# %%
import numpy as np
import codecs
import re
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
filename = "../indie/ALL.txt"
# First go the file once to see how big it is and to build the vocab
token_to_idx = {}
total_size = 0
with codecs.open(filename, 'r', 'utf-8') as f:
    for line in f:
        total_size += len(line)
        words = filter(lambda a: a != '', re.split('([\.\?\n\t\(\)\s,!"]+)', line))
        for w in words:
            w = w.lower()
            if w not in token_to_idx:
                token_to_idx[w] = len(token_to_idx) + 1

# %%
len(token_to_idx)
#TODO clear some useless words (e.g. '')
# Out:
# 3577

# %%
token_to_idx
# Out:
# {u'daremo': 468,
#  u'assurde': 2903,
#  u'unica': 2106,
#  u'ciao': 1296,
#  u'dovrebbe': 1852,
#  u'd\xe9j\xe0': 1448,
#  u'imitavo': 1748,
#  u'jihad': 471,
#  u'sleep': 1957,
#  u'francesco': 479,
#  u'coprirti': 1432,
#  u'abbaia': 3573,
#  u'cambiami': 3274,
#  u'attimo': 1003,
#  u'bastata': 879,
#  u'porno': 1207,
#  u'piange': 1311,
#  u'presente': 2974,
#  u'poco': 655,
#  u"l'ultima": 2799,
#  u"rock'n'roll": 1683,
#  u'loro': 129,
#  u'fronte': 2986,
#  u'chicco': 1733,
#  u'libert\xe0': 499,
#  u'tremore': 3364,
#  u'riso': 1734,
#  u'annoiavo': 338,
#  u'felpa': 2554,
#  u'figa': 1654,
#  u'figo': 1750,
#  u'buche': 3422,
#  u'legami': 3329,
#  u'calcio': 847,
#  u'scelto': 2855,
#  u"dell'altro": 2414,
#  u'chiamami': 2452,
#  u'impazzire': 3136,
#  u'poche': 3030,
#  u'vederti': 2265,
#  u'l\u2019aria': 3142,
#  u'remi': 543,
#  u'piccioni': 2083,
#  u"d'auto": 1799,
#  u'appeso': 642,
#  u'pavimento': 2586,
#  u'strettie': 3220,
#  u'reggio-calabria': 730,
#  u'dandomi': 2616,
#  u'sincronizzato': 1612,
#  u'andr\xf2': 1310,
#  u'occhiate': 3381,
#  u'valgono': 696,
#  u'sorridente': 2293,
#  u'cammino': 462,
#  u'costeggiavano': 537,
#  u'andr\xe0': 1833,
#  u'lisciatevi': 3342,
#  u'cammini': 1705,
#  u'cammina': 2556,
#  u'tipi': 1289,
#  u'nel': 96,
#  u"com'\xe8": 2199,
#  u'tipo': 423,
#  u'nei': 94,
#  u'telegiornale': 1474,
#  u'circondato': 805,
#  u"m'hai": 1402,
#  u'viviamo': 273,
#  u'tacchi': 2346,
#  u'semafori': 1507,
#  u'errore': 2205,
#  u'chiedermelo': 1301,
#  u'sogno': 1147,
#  u'new': 230,
#  u'fingere': 2548,
#  u'riattacchi': 3113,
#  u'annego': 2399,
#  u'coraggio': 999,
#  u'rimedio': 1651,
#  u'godersi': 2924,
#  u'colletto': 3489,
#  u'culo': 3324,
#  u'colletti': 3333,
#  u'accompagnare': 319,
#  u'sciarpa': 3550,
#  u'facevo': 2198,
#  u'serviva': 304,
#  u'avere': 282,
#  u'abbronza': 3365,
#  u'sedile': 2168,
#  u'seduta': 3150,
#  u'sogni': 2088,
#  u'moltiplicare': 3431,
#  u'gli': 545,
#  u'capirne': 2668,
#  u'languidi': 2741,
#  u'stupisco': 883,
#  u'chiede': 3543,
#  u'dovuto': 1173,
#  u'resti': 1466,
#  u'scoprire': 787,
#  u'resto': 673,
#  u'generale': 2636,
#  u'parlano': 20,
#  u'nulla': 1496,
#  u'resta': 2047,
#  u'+': 2978,
#  u'parlamento': 716,
#  u'sorridi': 1982,
#  u'scavare': 2058,
#  u'divide': 1843,
#  u'brama': 1322,
#  u'costole': 1823,
#  u'attento': 1624,
#  u'frasi': 3157,
#  u'negativi': 1881,
#  u'versavi': 1893,
#  u'timore': 3362,
#  u'n\u2019esco': 1259,
#  u'qualunque': 1014,
#  u'sgomita': 1515,
#  u'gialli': 2540,
#  u'lividi': 2322,
#  u'bellissima': 1101,
#  u'call': 106,
#  u'armi': 1351,
#  u'ora': 1395,
#  u'sembra': 1028,
#  u'renderti': 1454,
#  u'devasta': 986,
#  u'perdonato': 3099,
#  u'inverno': 1115,
#  u'nord': 3062,
#  u'schiaffi': 2941,
#  u'affetto': 3330,
#  u'quali': 544,
#  u'salvagente': 137,
#  u'inganna': 985,
#  u'd\u2019occhio': 1482,
#  u'abbiamo': 740,
#  u'lungo': 1148,
#  u'inganno': 2612,
#  u'l\u2019autostop': 1048,
#  u'quale': 2043,
#  u'me': 55,
#  u'fossimo': 429,
#  u'ma': 56,
#  u'morire': 403,
#  u'ed': 379,
#  u'mo': 2085,
#  u'frena': 551,
#  u'mi': 26,
#  u'era': 300,
#  u'guardavo': 1747,
#  u'ero': 121,
#  u'my': 1958,
#  u'eri': 348,
#  u'gloria': 1320,
#  u'cucinare': 387,
#  u'attorcigliano': 1941,
#  u'vodka': 2736,
#  u'andrebbe': 3048,
#  u'accontenti': 3004,
#  u'messa': 2954,
#  u'coperte': 1268,
#  u'aaaa': 2522,
#  u'distinguo': 2086,
#  u"d'indennit\xe0": 3002,
#  u'corsia': 406,
#  u'camicia': 3237,
#  u'aaah': 2422,
#  u'salpano': 3020,
#  u'dormissi': 276,
#  u'suoni': 2633,
#  u"l'aria": 3538,
#  u'cielo': 432,
#  u'cieli': 1094,
#  u'stasera': 385,
#  u'suono': 1491,
#  u'lesioni': 1797,
#  u'suona': 308,
#  u'farci': 1197,
#  u'lavare': 3562,
#  u'slalom': 1199,
#  u'svastica': 297,
#  u'indaco': 1424,
#  u'amarti': 2278,
#  u'aiuter\xe0': 2599,
#  u'bandiere': 1582,
#  u'rincorriamo': 2919,
#  u"l'espressione": 3318,
#  u'pizza': 449,
#  u'svegliami': 3264,
#  u'caldo': 82,
#  u'abbatte': 1935,
#  u'prendiamo': 3206,
#  u'cadillac': 1986,
#  u'miia': 3392,
#  u'prestare': 1641,
#  u'mesi': 2695,
#  u"d'estate": 3236,
#  u'aspettare': 844,
#  u'mese': 2895,
#  u'bevi': 2735,
#  u'morir\xe0': 470,
#  u'ascoltarla': 3247,
#  u'padre': 418,
#  u'arrivano': 3240,
#  u'padri': 3366,
#  u'credenti': 3375,
#  u'fiamme': 310,
#  u'noiose': 2750,
#  u'youporn': 316,
#  u'danni': 3563,
#  u'proteeeeggi': 3299,
#  u'tagli': 1923,
#  u'vere': 2651,
#  u'bevo': 452,
#  u"l'idolo": 1883,
#  u'donare': 893,
#  u'nostra': 1813,
#  u'nostre': 737,
#  u'superattico': 2618,
#  u'nostri': 2537,
#  u'vita': 439,
#  u'piovono': 1803,
#  u'prendo': 3032,
#  u'vite': 902,
#  u'ormai': 804,
#  u'vento': 744,
#  u'stronza': 1510,
#  u'terrai': 2999,
#  u'stronzo': 792,
#  u'gente': 424,
#  u',': 2120,
#  u'qualcosa': 741,
#  u'unire': 1019,
#  u'"..."\n': 3209,
#  u'diventano': 542,
#  u'reggono': 2802,
#  u'fin': 1061,
#  u'moriremo': 3258,
#  u'triangolo': 2402,
#  u'trema': 3537,
#  u'viola': 2282,
#  u'dimentichiamo': 3201,
#  u'maledetto': 2826,
#  u'enrico': 3490,
#  u'cadde': 3556,
#  u'lenti': 2291,
#  u'riesci': 1096,
#  u'riesco': 384,
#  u'dipende': 899,
#  u'cantava': 2673,
#  u'ricordati': 2482,
#  u'giusto': 1502,
#  u'niente': 104,
#  u'ridevamo': 2533,
#  u"l'ultimo": 491,
#  u'l': 3103,
#  u'pazzi': 2536,
#  u'luce': 748,
#  u'poterlo': 2951,
#  u'panino': 777,
#  u'cresciamo': 2649,
#  u'luci': 156,
#  u'suonare': 1060,
#  u'cuffie': 1331,
#  u'angolo': 3359,
#  u'angoli': 2487,
#  u'potevo': 1161,
#  u'livorno': 2810,
#  u'parliamo': 3316,
#  u"nell'oblio": 2443,
#  u'zenzero': 2608,
#  u'memoria': 2195,
#  u"sull'uno": 3378,
#  u'vada': 1703,
#  u'immagina': 1709,
#  u'tolta': 2953,
#  u'immagine': 2055,
#  u'cimitero': 2406,
#  u'immagini': 585,
#  u'vado': 482,
#  u'colazione': 1081,
#  u'pensare': 454,
#  u'manda': 2405,
#  u'volare': 1026,
#  u'esistano': 1279,
#  u'appesi': 2698,
#  u'mandi': 1511,
#  u'forti': 2273,
#  u'sposare': 3046,
#  u'foto': 631,
#  u'andarmene': 2543,
#  u'sanremo': 1016,
#  u'intanto': 2398,
#  u'anziani': 697,
#  u'?\t\n': 1554,
#  u'marchiate': 1240,
#  u'scoprirete': 739,
#  u'topo': 3434,
#  u'accetti': 1052,
#  u'sorso': 1628,
#  u'chiaro': 1166,
#  u'baleno': 1494,
#  u'muori': 1773,
#  u'dischi': 1752,
#  u'cerotti': 2590,
#  u'balena': 678,
#  u'vorrai': 3548,
#  u'starti': 815,
#  u'speedy': 1988,
#  u'sudore': 1753,
#  u'mischiando': 1693,
#  u'preferirei': 500,
#  u'passate': 1672,
#  u'avrebbe': 1370,
#  u'tuoi': 186,
#  u'vivere': 976,
#  u'sorella': 2382,
#  u"d'uscita": 2044,
#  u'piangerai': 2365,
#  u'tanga': 1216,
#  u'midi': 1980,
#  u'equilibrio': 2853,
#  u'peggio': 1865,
#  u'lego': 1164,
#  u'lega': 1013,
#  u'lasciarmi': 795,
#  u'bilocale': 1328,
#  u'cemento': 3040,
#  u"dall'inferno": 2821,
#  u'maniche': 3488,
#  u'solamente': 866,
#  u'splendeva': 2671,
#  u'ragione': 1145,
#  u'continuamente': 2838,
#  u'firestarter': 1585,
#  u'cinquantenni': 3352,
#  u'perdute': 2757,
#  u'quattro': 321,
#  u'giocavi': 3575,
#  u'serve': 1054,
#  u'tee': 2562,
#  u'alberi': 3190,
#  u'lottare': 1312,
#  u'avanza': 290,
#  u'albero': 573,
#  u'mattina': 1079,
#  u'primavera': 2660,
#  u'cuscino': 2186,
#  u'prego': 78,
#  u'dirmi': 2385,
#  u'pella': 809,
#  u'esploder\xe0': 1839,
#  u'campo': 311,
#  u'calda': 3496,
#  u'prega': 1714,
#  u'roccia': 2453,
#  u"l'ombrellone": 3235,
#  u'dovremmo': 1136,
#  u'sabato': 2553,
#  u'ancora': 320,
#  u'berlino': 3038,
#  u'salutare': 1073,
#  u'conquistano': 528,
#  u'contento': 2911,
#  u'urlano': 2062,
#  u'contenti': 2916,
#  u'brillo': 3078,
#  u'schegge': 2298,
#  u'contenta': 2852,
#  u'un\u2019aquila': 3028,
#  u'cannocchiale': 663,
#  u'smettere': 872,
#  u'rap': 2390,
#  u'spiaggia': 507,
#  u'difettosi': 2574,
#  u'capitato': 719,
#  u'cortile': 3574,
#  u'viverla': 3243,
#  u'crepano': 3326,
#  u'reale': 3029,
#  u'partecipare': 2918,
#  u'greta': 2645,
#  u"d'accordo": 1348,
#  u'c-coez': 1894,
#  u'diretti': 1978,
#  u'lattea': 3306,
#  u'trovarmi': 2515,
#  u"l'oro": 2256,
#  u'! \n': 2407,
#  u'cenere': 3557,
#  u'acquazzone': 1151,
#  u'struzzi': 3428,
#  u'oltre': 3437,
#  u'aspetto': 849,
#  u'aspetta': 3076,
#  u'distinguere': 2887,
#  u'erano': 1760,
#  u'sospeso': 3143,
#  u'schiena': 2587,
#  u'mario': 3340,
#  u'tenerezza': 3107,
#  u'trovarsi': 1393,
#  u'sbiascico': 3156,
#  u'hanno': 698,
#  u'flop': 2392,
#  u'romantica': 2103,
#  u'cambio': 1699,
#  u'aiutarmi': 2831,
#  u'salsedine': 3345,
#  u'. \n': 1877,
#  u'rivista': 1284,
#  u'mixo': 1575,
#  u'vicino': 900,
#  u'potevamo': 2879,
#  u'toccare': 2928,
#  u'colore': 771,
#  u'disturbo': 1325,
#  u'vicine': 1478,
#  u'random': 2072,
#  u'vicina': 1104,
#  u'paracetamolo': 44,
#  u'radio': 76,
#  u'lamentarsi': 2930,
#  u'macello': 2324,
#  u'deluso': 1468,
#  u"m'aspetto": 2046,
#  u'solitudine': 2140,
#  u'pinocchio': 641,
#  u'indovinato': 596,
#  u'gioia': 3185,
#  u'stanza': 1214,
#  u'delusa': 1467,
#  u'distruggere': 2982,
#  u'meno': 592,
#  u'dolore': 1637,
#  u'dolori': 3115,
#  u'dormiremo': 2948,
#  u'capacit\xe0': 2432,
#  u'luccica': 1764,
#  u'do': 1282,
#  u'perderti': 259,
#  u'regalato': 2363,
#  u'di': 40,
#  u'de': 421,
#  u'sardegna': 508,
#  u'da': 54,
#  u'bevuta': 2970,
#  u'cresciuti': 2271,
#  u'esserlo': 2258,
#  u'intorno': 519,
#  u'andrai': 1309,
#  u'alza': 3297,
#  u'vestiti': 520,
#  u'bar': 706,
#  u'situazione': 2843,
#  u'rispetto': 1911,
#  u'vestito': 912,
#  u'alzi': 3477,
#  u'vestita': 2266,
#  u'respirare': 402,
#  u'bottiglia': 3469,
#  u'stiamo': 2866,
#  u'disco': 1338,
#  u'cerchio': 1237,
#  u'anzi': 1388,
#  u'traslocare': 2894,
#  u'ammazza': 975,
#  u'bleu': 1900,
#  u'ritrovare': 1042,
#  u'guerra': 994,
#  u'cerco': 662,
#  u'consapevolmente': 2411,
#  u'semicerchi': 2309,
#  u'diranno': 3493,
#  u'prete': 911,
#  u'ragazzino': 1162,
#  u'conosciamo': 1457,
#  u'guance': 2275,
#  u'lavarti': 224,
#  u'scarabocchia': 1416,
#  u'pffh': 1483,
#  u'rende': 2772,
#  u'rattrista': 1287,
#  u'comprato': 263,
#  u'raccoglie': 3166,
#  u'pirati': 533,
#  u'chiama': 961,
#  u'yogurt': 1536,
#  u'pensieri': 193,
#  u'reggi': 1700,
#  u'sapere': 3404,
#  u"un'altra": 1352,
#  u'cicale': 1110,
#  u'tortora': 1529,
#  u'montagne': 779,
#  u'scusa': 394,
#  u'natura': 3440,
#  u'credi': 802,
#  u'montagna': 600,
#  u'scuse': 2648,
#  u'basteranno': 1778,
#  u'magazzino': 1754,
#  u'anche': 534,
#  u'd\xe0': 3184,
#  u'distrutto': 1327,
#  u'rime': 1652,
#  u'motta': 2973,
#  u'litigare': 301,
#  u'crescono': 2759,
#  u'cinte': 3369,
#  u'gratis': 3419,
#  u'negozi': 3529,
#  u'queste': 778,
#  u'urla': 756,
#  u'questa': 75,
#  u'consiglia': 2033,
#  u'questo': 826,
#  u'denti': 784,
#  u'compromesso': 2861,
#  u'una': 115,
#  u'insegne': 2213,
#  u'disag-io': 1604,
#  u'coi': 1090,
#  u'favore': 836,
#  u'tinge': 2479,
#  u'col': 133,
#  u'uno': 1076,
#  u'flavio': 2564,
#  u'pianto': 1123,
#  u'baciarti': 2274,
#  u'spezzati': 2909,
#  u'curare': 3344,
#  u'piante': 888,
#  u'portano': 214,
#  u'diventiamo': 1921,
#  u'funebre': 1051,
#  u'chiaro:': 1691,
#  u'matti': 2534,
#  u'strappo': 1156,
#  u'dipinti': 1095,
#  u'restarti': 427,
#  u'zitto': 684,
#  u'oooooo': 2523,
#  u"dov'ero": 2197,
#  u"quand'era": 2602,
#  u'petto': 1769,
#  u'imparare': 408,
#  u'scende': 343,
#  u'caff\xe8': 951,
#  u'abbracci': 2907,
#  u'life': 2121,
#  u'cio\xe8': 1067,
#  u'sperare': 2100,
#  u'correvamo': 2535,
#  u'gridandolo': 577,
#  u'pezzi': 1850,
#  u'ascoltami': 3242,
#  u'pezzo': 2394,
#  u'servito': 3481,
#  u'dipingerti': 2269,
#  u'aprire': 293,
#  u'perdevo': 2189,
#  u'militare': 3355,
#  u'avessimo': 1817,
#  u'guidate': 2338,
#  u'quaggi\xf9': 2159,
#  u'contare': 409,
#  u'assolato': 822,
#  u'avrei': 1172,
#  u'castro': 910,
#  u'dello': 1177,
#  u'forse': 237,
#  u'sapore': 365,
#  u'coglione': 3097,
#  u'delle': 882,
#  u'pagavo': 1751,
#  u'della': 868,
#  u'ritorni': 1620,
#  u'cane': 897,
#  u'ritorno': 401,
#  u"dall'elicottero": 2604,
#  u'indietro': 1004,
#  u'bio': 3411,
#  u'ritorna': 957,
#  u'distrazione': 2815,
#  u'it': 1719,
#  u'notti': 2920,
#  u'bruttissima': 2580,
#  u'il': 35,
#  u'io': 33,
#  u'in': 68,
#  u"l'insalata": 437,
#  u'sbagliata': 3244,
#  u'farsi': 1036,
#  u'ogni': 717,
#  u'bottiglie': 1825,
#  u'bello': 660,
#  u'lavorare': 1117,
#  u'belli': 2326,
#  u'nike': 1519,
#  u'belle': 1796,
#  u'scrivo': 1406,
#  u'aveva': 2109,
#  u'bella': 183,
#  u'citt\xe0': 157,
#  u'bastardo': 2212,
#  u'perfetto': 2854,
#  u'\ufffdsto': 1729,
#  u'salita': 2135,
#  u'consente': 2410,
#  u'manchi': 369,
#  u'finir\xe0': 2419,
#  u'regalarti': 1223,
#  u'consento': 606,
#  u'satelliti': 2310,
#  u"un'immagine": 965,
#  u'persa': 1541,
#  u'topi': 434,
#  u'fusa': 2588,
#  u'costruito': 2263,
#  u'passato': 2253,
#  u'traffico': 1520,
#  u'serate': 1671,
#  u'piazza': 1032,
#  u'presto': 1265,
#  u'subirlo': 3472,
#  u'orgasmo': 236,
#  u'"\n': 1427,
#  u'schiaccio': 1516,
#  u'mamma': 415,
#  u'sedia': 3313,
#  u'roma': 2795,
#  u'the': 1569,
#  u'tenerci': 1461,
#  u'borsa': 2066,
#  u'yeh': 1232,
#  u"l'indiano": 942,
#  u'amami': 1168,
#  u'cerchi': 2307,
#  u'prenditi': 2980,
#  u'chiuderti': 3439,
#  u'scoperto': 3463,
#  u'saltare': 916,
#  u'bubu': 1269,
#  u'disegno': 1144,
#  u'gode': 2007,
#  u'voglia': 203,
#  u'hai': 17,
#  u'sfidi': 1991,
#  u'han': 2819,
#  u'svegliare': 3065,
#  u'salutami': 414,
#  u'terrazza': 2845,
#  u'voglio': 395,
#  u'vuoti': 2923,
#  u'vuoto': 1547,
#  u'cucina': 1082,
#  u'scoperta': 2846,
#  u'vuote': 704,
#  u'migliori': 3219,
#  u'bastarda': 1664,
#  u'migliore': 2101,
#  u'online': 3414,
#  u'ricorder\xf3': 2544,
#  u'scatti': 1505,
#  u'capo': 328,
#  u"un'onda": 598,
#  u'ferragosto': 1118,
#  u'sapevo': 2207,
#  u'margherite': 2330,
#  u'nudo': 202,
#  u'prometto': 2709,
#  u'scarpe': 1580,
#  u'nudi': 2203,
#  u'nude': 1954,
#  u'sputare': 1649,
#  u'rotolano': 2073,
#  u'falla': 3433,
#  u'gandhi': 1918,
#  u"l'altro": 2409,
#  u'palchi': 1685,
#  u'clich\xe9': 1228,
#  u'verranno': 2933,
#  u'scuri': 1556,
#  u'parli': 1878,
#  u'scura': 1247,
#  u'neve': 885,
#  u'andartene': 2494,
#  u'ritroviamoci': 2947,
#  u'facendo': 1047,
#  u'fisso': 506,
#  u'finivano': 3007,
#  u'anello': 1224,
#  u"d'acqua": 3233,
#  u'gridare': 895,
#  u'correre': 2185,
#  u'silenzi': 2781,
#  u'decidono': 3148,
#  u'serpente': 892,
#  u'gradino': 2878,
#  u'globo': 940,
#  u'vede': 16,
#  u'uragano': 1934,
#  u'giocata': 3234,
#  u'l\u2019otto': 3515,
#  u'vedo': 445,
#  u'strade': 213,
#  u'strada': 865,
#  u'vedi': 336,
#  u'dolce': 953,
#  u'sarai': 2486,
#  u'lampo': 2152,
#  u'scordarti': 2480,
#  u'giacca': 1544,
#  u'opzioni': 1350,
#  u'collasso': 3522,
#  u'braccio': 1716,
#  u'braccia': 541,
#  u'trovartene': 2485,
#  u'neon': 3307,
#  u'cacciavo': 1428,
#  u'spaventa': 2076,
#  u'mancher\xf2': 152,
#  u'sbronzarmi': 3227,
#  u'ricordavi': 2884,
#  u'o': 70,
#  u'algi': 3427,
#  u'perplessit\xe0': 2995,
#  u'gioiello': 1226,
#  u'affogo': 2678,
#  u'bisogno': 2896,
#  u'dignit\xe0': 3123,
#  u'volerai': 2246,
#  u"un'amica": 267,
#  u'correndo': 3096,
#  u'dicevo': 3494,
#  u'cartina': 1836,
#  u'selfie': 3022,
#  u'specchio': 223,
#  u'nervi': 919,
#  u"d'affari": 3370,
#  u'son': 870,
#  u'mangiarsi': 2927,
#  u'rotto': 1160,
#  u'smetto': 1298,
#  u'dovevo': 2126,
#  u'risbatte': 188,
#  u'accarezza': 764,
#  u'andando': 2496,
#  u'rotte': 1824,
#  u'rotta': 1103,
#  u'n\xe9': 285,
#  u'accordi': 2064,
#  u'fiume': 1114,
#  u'ostacoli': 2285,
#  u'gregge': 1816,
#  u'rispondi': 197,
#  u'panorama': 749,
#  u'mordevi': 3386,
#  u'rispondo': 3060,
#  u'viso': 2658,
#  u'stipendio': 3415,
#  u'tombino': 2687,
#  u'lago': 599,
#  u'sembri': 2910,
#  u'streghe': 3457,
#  u'bagno': 556,
#  u'bagni': 2967,
#  u'rimettersi': 2318,
#  u"l'accender\xe0": 1838,
#  u'bagna': 3541,
#  u'stereo': 1772,
#  u'pochissime': 2962,
#  u'spunta': 3480,
#  u'bere': 393,
#  u'rivedo': 670,
#  u'verde': 518,
#  u'diventare': 2539,
#  u'ripercuote': 995,
#  u'ritroveremo': 823,
#  u'viva': 3462,
#  u'pesa': 1452,
#  u'vergognare': 2289,
#  u'all\u2019acqua': 3561,
#  u'streaming': 3398,
#  u'vorrei': 318,
#  u'polso': 3499,
#  u'manger\xf2': 3466,
#  u'vivo': 3459,
#  u'peso': 1283,
#  u'pagine': 2356,
#  u'crystal': 1280,
#  u'fermo': 835,
#  u'intero': 2306,
#  u'pagina': 2340,
#  u'moicani': 492,
#  u'ferma': 669,
#  u'mettermi': 1367,
#  u"c'\xe8": 477,
#  u'bicchiere': 453,
#  u'sudate': 3323,
#  u'rifiuti': 3471,
#  u'minaj': 1607,
#  u'tonno': 682,
#  u'saremo': 1898,
#  u'allontana': 1324,
#  u'maglie': 3239,
#  u'magnifico': 853,
#  u'vogliam': 3351,
#  u'guardarsi': 785,
#  u'stacco': 2395,
#  u'mutande': 216,
#  u'scritto': 1153,
#  u'tesi': 2716,
#  u'no': 425,
#  u'riparare': 3010,
#  u'visto': 504,
#  u'ne': 9,
#  u'gi\xf9': 400,
#  u'gi\xe0': 1300,
#  u'neanche': 1701,
#  u'commerciale': 2628,
#  u'likebella': 2430,
#  u'filanti': 2705,
#  u'levarci': 1463,
#  u'sballo': 3409,
#  u'troverei': 980,
#  u'canto': 63,
#  u'nodo': 2956,
#  u'muove': 1504,
#  u'richiamo': 1409,
#  u'dobbiamo': 1442,
#  u'sbaglia': 3283,
#  u'chiusa': 227,
#  u'lottato': 1397,
#  u'acqua': 603,
#  u'avanti': 1692,
#  u'fiorisce': 946,
#  u"all'altoparlante": 2192,
#  u'smentita': 2045,
#  u'sbaglio': 457,
#  u'chiuso': 196,
#  u'accosta': 1626,
#  u'quindi': 2676,
#  u'trib\xf9': 3443,
#  u'inutile': 1990,
#  u'seitan': 1598,
#  u'siedi': 3483,
#  u'distanza': 566,
#  u"dall'impatto": 2448,
#  u'lunga': 723,
#  u'occhiali': 855,
#  u"l'ascolto": 2444,
#  u'rom': 312,
#  u'salopette': 1966,
#  u'scioglie': 668,
#  u'cos\xec': 32,
#  u'soffro': 3111,
#  u'inesorabilmente': 562,
#  u'vacanza': 3528,
#  u'correr\xf2': 2546,
#  u'denso': 2315,
#  u'corpo': 2034,
#  u'tradirti': 819,
#  u'sanno': 1414,
#  u'viceversa': 1540,
#  u'sconosciuto': 1077,
#  u'centrifughe': 3410,
#  u'giacche': 1584,
#  u'torno': 399,
#  u'torna': 2223,
#  u'tonsille': 47,
#  u'puoi': 51,
#  u'l\u2019orecchio': 101,
#  u'quasi': 2756,
#  u'fenicottero': 2605,
#  u'provate': 1687,
#  u'portarmi': 3492,
#  u'preciso': 1802,
#  u'pettinavi': 2988,
#  u'finiscono': 2237,
#  u'pugno': 2057,
#  u"l'estate": 766,
#  u'votare': 1012,
#  u'pugni': 1862,
#  u'crescere': 1939,
#  u'allagare': 557,
#  u'minuto': 1695,
#  u'fratelli': 1632,
#  u'mordeva': 2672,
#  u'proteggi': 3288,
#  u'dio': 1653,
#  u'affollata': 3286,
#  u'fragile': 3006,
#  u'brindo': 1423,
#  u"d'ombretto": 2171,
#  u'posto': 128,
#  u'svelto': 498,
#  u'soffri': 2259,
#  u'continuate': 2132,
#  u'carte': 1586,
#  u'posti': 1317,
#  u'sciolgono': 1500,
#  u'poste': 709,
#  u'aperto': 607,
#  u'aperti': 675,
#  u'boccia': 2450,
#  u'guardando': 867,
#  u'suonatore': 1152,
#  u'cose': 126,
#  u'treno': 71,
#  u'treni': 582,
#  u'cosa': 182,
#  u'brava': 1180,
#  u'bravo': 1163,
#  u'intelligente': 347,
#  u'cosi': 1644,
#  u'iniziare': 1362,
#  u"l'abitudine": 2144,
#  u'sfogo': 1588,
#  u'celestini': 441,
#  u'vengo': 832,
#  u'nello': 1380,
#  u'starmene': 2721,
#  u'pianura': 245,
#  u'cassa': 2998,
#  u"dell'umore": 3546,
#  u'scade': 2874,
#  u'pessima': 2662,
#  u'berrettoqui': 3212,
#  u"s'avveri": 759,
#  u'uguali': 2361,
#  u'liquore': 2483,
#  u'agosto': 85,
#  u'saresti': 3571,
#  u'uguale': 1553,
#  u'macchine': 2005,
#  u'alzarmi': 1358,
#  u"l'amavo": 2114,
#  u'tira': 3320,
#  u'macchina': 859,
#  u'rinascere': 3271,
#  u'muovermi': 3383,
#  u're': 1895,
#  u'negli': 112,
#  u'dice': 1807,
#  u'alto': 1056,
#  u'probabilmente': 2115,
#  u'fenomeni': 874,
#  u"dell'estate": 2631,
#  u'dandogli': 2615,
#  u'buca': 1768,
#  u'alta': 3216,
#  u'boh': 1174,
#  u'molto': 647,
#  u'potrebbe': 1473,
#  u'sputi': 221,
#  u'graffi': 2532,
#  u'molte': 751,
#  u'l\u2019orologio': 3498,
#  u'molta': 927,
#  u'effetto': 1669,
#  u"t'incazzerai": 2364,
#  u'renato': 2403,
#  u'controllavo': 3502,
#  u'muscoli': 3114,
#  u'buttare': 388,
#  u'scommesse': 3413,
#  u'enorme': 2222,
#  u'italiano': 3535,
#  u'lasciati': 2804,
#  u'basterebbe': 3069,
#  u'lasciato': 93,
#  u'boschi': 1126,
#  u'luned\xec': 2526,
#  u'spaccher\xf2': 366,
#  u'taciturnal': 1498,
#  u'sentirti': 3072,
#  u'prova': 3473,
#  u'prove': 1897,
#  u'provi': 1780,
#  u'provo': 3132,
#  u'cavalli': 3576,
#  u'iphone': 1613,
#  u'ahhh': 2557,
#  u'annaffio': 3059,
#  u'gridare:': 2413,
#  u'servir\xf2': 2354,
#  u'ristoranti': 3042,
#  u'oooooooh': 2090,
#  u'salta': 757,
#  u'ooooooo': 2524,
#  u'ridere': 461,
#  u'ooooooh': 2071,
#  u'evitare': 3124,
#  ...}

# %%
# now tokenize the whole text file, using the dictionary created
token_text = []
with codecs.open(filename, 'r', 'utf-8') as f:
    for line in f:
        total_size += len(line)
        words = re.split('([\.\?\n\t\(\)\s,!"]+)', line)
        token_text += [token_to_idx[w.lower()] for w in words]

# %%
len(token_text)
# Out:
# 67369

# %%
# prepare the dataset of input sequences (10 words) to output (1 word) pairs
seq_length = 10 # length of word sequences used for predictions
dataX = []
dataY = []
for i in range(0, len(token_text) - seq_length):
    seq_in = token_text[i:i + seq_length]
    seq_out = token_text[i + seq_length]
    dataX.append(seq_in)
    dataY.append(seq_out)
n_patterns = len(dataX)
print "Total Patterns: ", n_patterns
# Out:
# Total Patterns:  67359

# %%
print dataX[0], '-->', dataY[0]
# Out:
# [1, 2, 3, 2, 4, 2, 5, 2, 6, 2] --> 7

# %%
# create numpy arrays from lists
X = np.reshape(np.array(dataX), (n_patterns, seq_length, 1))
y = np.array(dataY)

# %%
X.shape
# Out:
# (67359, 10, 1)

# %%
n_neurons = seq_length
n_epoch = 20
n_batch = 128

# %%
y = np_utils.to_categorical(y)

# %%
# create LSTM
model = Sequential()
model.add(LSTM(n_neurons, input_shape=X[0].shape))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 10)                480
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3579)              39369
# =================================================================
# Total params: 39,849
# Trainable params: 39,849
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
filepath="model-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True,mode='min')
callbacks_l = [checkpoint]

# %%
# train LSTM
model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2, callbacks=callbacks_l)
# Out:
# Epoch 1/20
#  - 47s - loss: 5.4965
#
# Epoch 00001: loss improved from inf to 5.49646, saving model to model-01-5.4965.hdf5
# Epoch 2/20
#  - 43s - loss: 4.1986
#
# Epoch 00002: loss improved from 5.49646 to 4.19860, saving model to model-02-4.1986.hdf5
# Epoch 3/20
#  - 43s - loss: 3.9364
#
# Epoch 00003: loss improved from 4.19860 to 3.93641, saving model to model-03-3.9364.hdf5
# Epoch 4/20
#  - 43s - loss: 3.7706
#
# Epoch 00004: loss improved from 3.93641 to 3.77057, saving model to model-04-3.7706.hdf5
# Epoch 5/20
#  - 43s - loss: 3.6900
#
# Epoch 00005: loss improved from 3.77057 to 3.68997, saving model to model-05-3.6900.hdf5
# Epoch 6/20
#  - 43s - loss: 3.6492
#
# Epoch 00006: loss improved from 3.68997 to 3.64918, saving model to model-06-3.6492.hdf5
# Epoch 7/20
#  - 43s - loss: 3.6248
#
# Epoch 00007: loss improved from 3.64918 to 3.62481, saving model to model-07-3.6248.hdf5
# Epoch 8/20
#  - 43s - loss: 3.6105
#
# Epoch 00008: loss improved from 3.62481 to 3.61049, saving model to model-08-3.6105.hdf5
# Epoch 9/20
#  - 43s - loss: 3.6007
#
# Epoch 00009: loss improved from 3.61049 to 3.60070, saving model to model-09-3.6007.hdf5
# Epoch 10/20
#  - 43s - loss: 3.5908
#
# Epoch 00010: loss improved from 3.60070 to 3.59078, saving model to model-10-3.5908.hdf5
# Epoch 11/20
#  - 43s - loss: 3.5829
#
# Epoch 00011: loss improved from 3.59078 to 3.58292, saving model to model-11-3.5829.hdf5
# Epoch 12/20
#  - 45s - loss: 3.5740
#
# Epoch 00012: loss improved from 3.58292 to 3.57399, saving model to model-12-3.5740.hdf5
# Epoch 13/20
#  - 44s - loss: 3.5466
#
# Epoch 00013: loss improved from 3.57399 to 3.54665, saving model to model-13-3.5466.hdf5
# Epoch 14/20
#  - 43s - loss: 3.5327
#
# Epoch 00014: loss improved from 3.54665 to 3.53274, saving model to model-14-3.5327.hdf5
# Epoch 15/20
#  - 49s - loss: 3.5150
#
# Epoch 00015: loss improved from 3.53274 to 3.51500, saving model to model-15-3.5150.hdf5
# Epoch 16/20
#  - 47s - loss: 3.5092
#
# Epoch 00016: loss improved from 3.51500 to 3.50925, saving model to model-16-3.5092.hdf5
# Epoch 17/20
#  - 48s - loss: 3.4996
#
# Epoch 00017: loss improved from 3.50925 to 3.49957, saving model to model-17-3.4996.hdf5
# Epoch 18/20
#  - 45s - loss: 3.4904
#
# Epoch 00018: loss improved from 3.49957 to 3.49043, saving model to model-18-3.4904.hdf5
# Epoch 19/20
#  - 44s - loss: 3.4852
#
# Epoch 00019: loss improved from 3.49043 to 3.48518, saving model to model-19-3.4852.hdf5
# Epoch 20/20
#  - 45s - loss: 3.4764
#
# Epoch 00020: loss improved from 3.48518 to 3.47640, saving model to model-20-3.4764.hdf5

# %%
idx_to_token = dict()
for k in token_to_idx.iteritems():
    idx_to_token[k[1]] = k[0]

# %%
len(idx_to_token)
# Out:
# 3578

# %%
idx_to_token[np.argmax(y[582])]
# Out:
# u'di'

# %%
n_vocab = len(token_to_idx)
# pick a random seed
start = np.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print "Seed:"
print "\"", ''.join([idx_to_token[value] for value in pattern]), "\""
# generate characters
for i in range(10):
    x = np.reshape(pattern, (1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = idx_to_token[index]
    print "DBG ---- Pred:", result, "for", x
    seq_in = [idx_to_token[value] for value in pattern]
    print result,
    pattern.append(index)
    pattern = pattern[1:len(pattern)]
print "\nDone."
# Out:
# Seed:
# " odiarmi se fisso l'arancione dei  "
# DBG ---- Pred:  for [[[  9.01062046e-01]
#   [  5.58971492e-04]
#   [  2.23588597e-03]
#   [  5.58971492e-04]
#   [  1.41699273e-01]
#   [  5.58971492e-04]
#   [  9.01341532e-01]
#   [  5.58971492e-04]
#   [  7.93739519e-02]
#   [  5.58971492e-04]]]
#  DBG ---- Pred:  for [[[  5.58971492e-04]
#   [  2.23588597e-03]
#   [  5.58971492e-04]
#   [  1.41699273e-01]
#   [  5.58971492e-04]
#   [  9.01341532e-01]
#   [  5.58971492e-04]
#   [  7.93739519e-02]
#   [  5.58971492e-04]
#   [  3.63331470e-03]]]
#  DBG ---- Pred:  for [[[  2.23588597e-03]
#   [  5.58971492e-04]
#   [  1.41699273e-01]
#   [  5.58971492e-04]
#   [  9.01341532e-01]
#   [  5.58971492e-04]
#   [  7.93739519e-02]
#   [  5.58971492e-04]
#   [  3.63331470e-03]
#   [  3.63331470e-03]]]
#  DBG ---- Pred:  for [[[  5.58971492e-04]
#   [  1.41699273e-01]
#   [  5.58971492e-04]
#   [  9.01341532e-01]
#   [  5.58971492e-04]
#   [  7.93739519e-02]
#   [  5.58971492e-04]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]]]
#  DBG ---- Pred:  for [[[  1.41699273e-01]
#   [  5.58971492e-04]
#   [  9.01341532e-01]
#   [  5.58971492e-04]
#   [  7.93739519e-02]
#   [  5.58971492e-04]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]]]
#  DBG ---- Pred:  for [[[  5.58971492e-04]
#   [  9.01341532e-01]
#   [  5.58971492e-04]
#   [  7.93739519e-02]
#   [  5.58971492e-04]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]]]
#  DBG ---- Pred:  for [[[  9.01341532e-01]
#   [  5.58971492e-04]
#   [  7.93739519e-02]
#   [  5.58971492e-04]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]
#   [  3.63331470e-03]]]
#  DBG ---- Pred:  for [[[ 0.00055897]
#   [ 0.07937395]
#   [ 0.00055897]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]]]
#  DBG ---- Pred:  for [[[ 0.07937395]
#   [ 0.00055897]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]]]
#  DBG ---- Pred:  for [[[ 0.00055897]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]
#   [ 0.00363331]]]
#
# Done.

# %%
value
# Out:
# 13
