# %%
import numpy as np
import codecs
import re
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
filename = "../indie/ALL.txt"
# First go the file once to see how big it is and to build the vocab
token_to_idx = {}
total_size = 0
with codecs.open(filename, 'r', 'utf-8') as f:
    for line in f:
        total_size += len(line)
        words = filter(lambda a: a != '', re.split('([\.\?\n\t\(\)\s,!"]+)', line))
        for w in words:
            w = w.lower()
            if w not in token_to_idx:
                token_to_idx[w] = len(token_to_idx) + 1

# %%
len(token_to_idx)
#TODO clear some useless words (e.g. '')
# Out:
# 3577

# %%
token_to_idx
# Out:
# {u'daremo': 468,
#  u'assurde': 2903,
#  u'unica': 2106,
#  u'ciao': 1296,
#  u'dovrebbe': 1852,
#  u'd\xe9j\xe0': 1448,
#  u'imitavo': 1748,
#  u'jihad': 471,
#  u'sleep': 1957,
#  u'francesco': 479,
#  u'coprirti': 1432,
#  u'abbaia': 3573,
#  u'cambiami': 3274,
#  u'attimo': 1003,
#  u'bastata': 879,
#  u'porno': 1207,
#  u'piange': 1311,
#  u'presente': 2974,
#  u'poco': 655,
#  u"l'ultima": 2799,
#  u"rock'n'roll": 1683,
#  u'loro': 129,
#  u'fronte': 2986,
#  u'chicco': 1733,
#  u'libert\xe0': 499,
#  u'tremore': 3364,
#  u'riso': 1734,
#  u'annoiavo': 338,
#  u'felpa': 2554,
#  u'figa': 1654,
#  u'figo': 1750,
#  u'buche': 3422,
#  u'legami': 3329,
#  u'calcio': 847,
#  u'scelto': 2855,
#  u"dell'altro": 2414,
#  u'chiamami': 2452,
#  u'impazzire': 3136,
#  u'poche': 3030,
#  u'vederti': 2265,
#  u'l\u2019aria': 3142,
#  u'remi': 543,
#  u'piccioni': 2083,
#  u"d'auto": 1799,
#  u'appeso': 642,
#  u'pavimento': 2586,
#  u'strettie': 3220,
#  u'reggio-calabria': 730,
#  u'dandomi': 2616,
#  u'sincronizzato': 1612,
#  u'andr\xf2': 1310,
#  u'occhiate': 3381,
#  u'valgono': 696,
#  u'sorridente': 2293,
#  u'cammino': 462,
#  u'costeggiavano': 537,
#  u'andr\xe0': 1833,
#  u'lisciatevi': 3342,
#  u'cammini': 1705,
#  u'cammina': 2556,
#  u'tipi': 1289,
#  u'nel': 96,
#  u"com'\xe8": 2199,
#  u'tipo': 423,
#  u'nei': 94,
#  u'telegiornale': 1474,
#  u'circondato': 805,
#  u"m'hai": 1402,
#  u'viviamo': 273,
#  u'tacchi': 2346,
#  u'semafori': 1507,
#  u'errore': 2205,
#  u'chiedermelo': 1301,
#  u'sogno': 1147,
#  u'new': 230,
#  u'fingere': 2548,
#  u'riattacchi': 3113,
#  u'annego': 2399,
#  u'coraggio': 999,
#  u'rimedio': 1651,
#  u'godersi': 2924,
#  u'colletto': 3489,
#  u'culo': 3324,
#  u'colletti': 3333,
#  u'accompagnare': 319,
#  u'sciarpa': 3550,
#  u'facevo': 2198,
#  u'serviva': 304,
#  u'avere': 282,
#  u'abbronza': 3365,
#  u'sedile': 2168,
#  u'seduta': 3150,
#  u'sogni': 2088,
#  u'moltiplicare': 3431,
#  u'gli': 545,
#  u'capirne': 2668,
#  u'languidi': 2741,
#  u'stupisco': 883,
#  u'chiede': 3543,
#  u'dovuto': 1173,
#  u'resti': 1466,
#  u'scoprire': 787,
#  u'resto': 673,
#  u'generale': 2636,
#  u'parlano': 20,
#  u'nulla': 1496,
#  u'resta': 2047,
#  u'+': 2978,
#  u'parlamento': 716,
#  u'sorridi': 1982,
#  u'scavare': 2058,
#  u'divide': 1843,
#  u'brama': 1322,
#  u'costole': 1823,
#  u'attento': 1624,
#  u'frasi': 3157,
#  u'negativi': 1881,
#  u'versavi': 1893,
#  u'timore': 3362,
#  u'n\u2019esco': 1259,
#  u'qualunque': 1014,
#  u'sgomita': 1515,
#  u'gialli': 2540,
#  u'lividi': 2322,
#  u'bellissima': 1101,
#  u'call': 106,
#  u'armi': 1351,
#  u'ora': 1395,
#  u'sembra': 1028,
#  u'renderti': 1454,
#  u'devasta': 986,
#  u'perdonato': 3099,
#  u'inverno': 1115,
#  u'nord': 3062,
#  u'schiaffi': 2941,
#  u'affetto': 3330,
#  u'quali': 544,
#  u'salvagente': 137,
#  u'inganna': 985,
#  u'd\u2019occhio': 1482,
#  u'abbiamo': 740,
#  u'lungo': 1148,
#  u'inganno': 2612,
#  u'l\u2019autostop': 1048,
#  u'quale': 2043,
#  u'me': 55,
#  u'fossimo': 429,
#  u'ma': 56,
#  u'morire': 403,
#  u'ed': 379,
#  u'mo': 2085,
#  u'frena': 551,
#  u'mi': 26,
#  u'era': 300,
#  u'guardavo': 1747,
#  u'ero': 121,
#  u'my': 1958,
#  u'eri': 348,
#  u'gloria': 1320,
#  u'cucinare': 387,
#  u'attorcigliano': 1941,
#  u'vodka': 2736,
#  u'andrebbe': 3048,
#  u'accontenti': 3004,
#  u'messa': 2954,
#  u'coperte': 1268,
#  u'aaaa': 2522,
#  u'distinguo': 2086,
#  u"d'indennit\xe0": 3002,
#  u'corsia': 406,
#  u'camicia': 3237,
#  u'aaah': 2422,
#  u'salpano': 3020,
#  u'dormissi': 276,
#  u'suoni': 2633,
#  u"l'aria": 3538,
#  u'cielo': 432,
#  u'cieli': 1094,
#  u'stasera': 385,
#  u'suono': 1491,
#  u'lesioni': 1797,
#  u'suona': 308,
#  u'farci': 1197,
#  u'lavare': 3562,
#  u'slalom': 1199,
#  u'svastica': 297,
#  u'indaco': 1424,
#  u'amarti': 2278,
#  u'aiuter\xe0': 2599,
#  u'bandiere': 1582,
#  u'rincorriamo': 2919,
#  u"l'espressione": 3318,
#  u'pizza': 449,
#  u'svegliami': 3264,
#  u'caldo': 82,
#  u'abbatte': 1935,
#  u'prendiamo': 3206,
#  u'cadillac': 1986,
#  u'miia': 3392,
#  u'prestare': 1641,
#  u'mesi': 2695,
#  u"d'estate": 3236,
#  u'aspettare': 844,
#  u'mese': 2895,
#  u'bevi': 2735,
#  u'morir\xe0': 470,
#  u'ascoltarla': 3247,
#  u'padre': 418,
#  u'arrivano': 3240,
#  u'padri': 3366,
#  u'credenti': 3375,
#  u'fiamme': 310,
#  u'noiose': 2750,
#  u'youporn': 316,
#  u'danni': 3563,
#  u'proteeeeggi': 3299,
#  u'tagli': 1923,
#  u'vere': 2651,
#  u'bevo': 452,
#  u"l'idolo": 1883,
#  u'donare': 893,
#  u'nostra': 1813,
#  u'nostre': 737,
#  u'superattico': 2618,
#  u'nostri': 2537,
#  u'vita': 439,
#  u'piovono': 1803,
#  u'prendo': 3032,
#  u'vite': 902,
#  u'ormai': 804,
#  u'vento': 744,
#  u'stronza': 1510,
#  u'terrai': 2999,
#  u'stronzo': 792,
#  u'gente': 424,
#  u',': 2120,
#  u'qualcosa': 741,
#  u'unire': 1019,
#  u'"..."\n': 3209,
#  u'diventano': 542,
#  u'reggono': 2802,
#  u'fin': 1061,
#  u'moriremo': 3258,
#  u'triangolo': 2402,
#  u'trema': 3537,
#  u'viola': 2282,
#  u'dimentichiamo': 3201,
#  u'maledetto': 2826,
#  u'enrico': 3490,
#  u'cadde': 3556,
#  u'lenti': 2291,
#  u'riesci': 1096,
#  u'riesco': 384,
#  u'dipende': 899,
#  u'cantava': 2673,
#  u'ricordati': 2482,
#  u'giusto': 1502,
#  u'niente': 104,
#  u'ridevamo': 2533,
#  u"l'ultimo": 491,
#  u'l': 3103,
#  u'pazzi': 2536,
#  u'luce': 748,
#  u'poterlo': 2951,
#  u'panino': 777,
#  u'cresciamo': 2649,
#  u'luci': 156,
#  u'suonare': 1060,
#  u'cuffie': 1331,
#  u'angolo': 3359,
#  u'angoli': 2487,
#  u'potevo': 1161,
#  u'livorno': 2810,
#  u'parliamo': 3316,
#  u"nell'oblio": 2443,
#  u'zenzero': 2608,
#  u'memoria': 2195,
#  u"sull'uno": 3378,
#  u'vada': 1703,
#  u'immagina': 1709,
#  u'tolta': 2953,
#  u'immagine': 2055,
#  u'cimitero': 2406,
#  u'immagini': 585,
#  u'vado': 482,
#  u'colazione': 1081,
#  u'pensare': 454,
#  u'manda': 2405,
#  u'volare': 1026,
#  u'esistano': 1279,
#  u'appesi': 2698,
#  u'mandi': 1511,
#  u'forti': 2273,
#  u'sposare': 3046,
#  u'foto': 631,
#  u'andarmene': 2543,
#  u'sanremo': 1016,
#  u'intanto': 2398,
#  u'anziani': 697,
#  u'?\t\n': 1554,
#  u'marchiate': 1240,
#  u'scoprirete': 739,
#  u'topo': 3434,
#  u'accetti': 1052,
#  u'sorso': 1628,
#  u'chiaro': 1166,
#  u'baleno': 1494,
#  u'muori': 1773,
#  u'dischi': 1752,
#  u'cerotti': 2590,
#  u'balena': 678,
#  u'vorrai': 3548,
#  u'starti': 815,
#  u'speedy': 1988,
#  u'sudore': 1753,
#  u'mischiando': 1693,
#  u'preferirei': 500,
#  u'passate': 1672,
#  u'avrebbe': 1370,
#  u'tuoi': 186,
#  u'vivere': 976,
#  u'sorella': 2382,
#  u"d'uscita": 2044,
#  u'piangerai': 2365,
#  u'tanga': 1216,
#  u'midi': 1980,
#  u'equilibrio': 2853,
#  u'peggio': 1865,
#  u'lego': 1164,
#  u'lega': 1013,
#  u'lasciarmi': 795,
#  u'bilocale': 1328,
#  u'cemento': 3040,
#  u"dall'inferno": 2821,
#  u'maniche': 3488,
#  u'solamente': 866,
#  u'splendeva': 2671,
#  u'ragione': 1145,
#  u'continuamente': 2838,
#  u'firestarter': 1585,
#  u'cinquantenni': 3352,
#  u'perdute': 2757,
#  u'quattro': 321,
#  u'giocavi': 3575,
#  u'serve': 1054,
#  u'tee': 2562,
#  u'alberi': 3190,
#  u'lottare': 1312,
#  u'avanza': 290,
#  u'albero': 573,
#  u'mattina': 1079,
#  u'primavera': 2660,
#  u'cuscino': 2186,
#  u'prego': 78,
#  u'dirmi': 2385,
#  u'pella': 809,
#  u'esploder\xe0': 1839,
#  u'campo': 311,
#  u'calda': 3496,
#  u'prega': 1714,
#  u'roccia': 2453,
#  u"l'ombrellone": 3235,
#  u'dovremmo': 1136,
#  u'sabato': 2553,
#  u'ancora': 320,
#  u'berlino': 3038,
#  u'salutare': 1073,
#  u'conquistano': 528,
#  u'contento': 2911,
#  u'urlano': 2062,
#  u'contenti': 2916,
#  u'brillo': 3078,
#  u'schegge': 2298,
#  u'contenta': 2852,
#  u'un\u2019aquila': 3028,
#  u'cannocchiale': 663,
#  u'smettere': 872,
#  u'rap': 2390,
#  u'spiaggia': 507,
#  u'difettosi': 2574,
#  u'capitato': 719,
#  u'cortile': 3574,
#  u'viverla': 3243,
#  u'crepano': 3326,
#  u'reale': 3029,
#  u'partecipare': 2918,
#  u'greta': 2645,
#  u"d'accordo": 1348,
#  u'c-coez': 1894,
#  u'diretti': 1978,
#  u'lattea': 3306,
#  u'trovarmi': 2515,
#  u"l'oro": 2256,
#  u'! \n': 2407,
#  u'cenere': 3557,
#  u'acquazzone': 1151,
#  u'struzzi': 3428,
#  u'oltre': 3437,
#  u'aspetto': 849,
#  u'aspetta': 3076,
#  u'distinguere': 2887,
#  u'erano': 1760,
#  u'sospeso': 3143,
#  u'schiena': 2587,
#  u'mario': 3340,
#  u'tenerezza': 3107,
#  u'trovarsi': 1393,
#  u'sbiascico': 3156,
#  u'hanno': 698,
#  u'flop': 2392,
#  u'romantica': 2103,
#  u'cambio': 1699,
#  u'aiutarmi': 2831,
#  u'salsedine': 3345,
#  u'. \n': 1877,
#  u'rivista': 1284,
#  u'mixo': 1575,
#  u'vicino': 900,
#  u'potevamo': 2879,
#  u'toccare': 2928,
#  u'colore': 771,
#  u'disturbo': 1325,
#  u'vicine': 1478,
#  u'random': 2072,
#  u'vicina': 1104,
#  u'paracetamolo': 44,
#  u'radio': 76,
#  u'lamentarsi': 2930,
#  u'macello': 2324,
#  u'deluso': 1468,
#  u"m'aspetto": 2046,
#  u'solitudine': 2140,
#  u'pinocchio': 641,
#  u'indovinato': 596,
#  u'gioia': 3185,
#  u'stanza': 1214,
#  u'delusa': 1467,
#  u'distruggere': 2982,
#  u'meno': 592,
#  u'dolore': 1637,
#  u'dolori': 3115,
#  u'dormiremo': 2948,
#  u'capacit\xe0': 2432,
#  u'luccica': 1764,
#  u'do': 1282,
#  u'perderti': 259,
#  u'regalato': 2363,
#  u'di': 40,
#  u'de': 421,
#  u'sardegna': 508,
#  u'da': 54,
#  u'bevuta': 2970,
#  u'cresciuti': 2271,
#  u'esserlo': 2258,
#  u'intorno': 519,
#  u'andrai': 1309,
#  u'alza': 3297,
#  u'vestiti': 520,
#  u'bar': 706,
#  u'situazione': 2843,
#  u'rispetto': 1911,
#  u'vestito': 912,
#  u'alzi': 3477,
#  u'vestita': 2266,
#  u'respirare': 402,
#  u'bottiglia': 3469,
#  u'stiamo': 2866,
#  u'disco': 1338,
#  u'cerchio': 1237,
#  u'anzi': 1388,
#  u'traslocare': 2894,
#  u'ammazza': 975,
#  u'bleu': 1900,
#  u'ritrovare': 1042,
#  u'guerra': 994,
#  u'cerco': 662,
#  u'consapevolmente': 2411,
#  u'semicerchi': 2309,
#  u'diranno': 3493,
#  u'prete': 911,
#  u'ragazzino': 1162,
#  u'conosciamo': 1457,
#  u'guance': 2275,
#  u'lavarti': 224,
#  u'scarabocchia': 1416,
#  u'pffh': 1483,
#  u'rende': 2772,
#  u'rattrista': 1287,
#  u'comprato': 263,
#  u'raccoglie': 3166,
#  u'pirati': 533,
#  u'chiama': 961,
#  u'yogurt': 1536,
#  u'pensieri': 193,
#  u'reggi': 1700,
#  u'sapere': 3404,
#  u"un'altra": 1352,
#  u'cicale': 1110,
#  u'tortora': 1529,
#  u'montagne': 779,
#  u'scusa': 394,
#  u'natura': 3440,
#  u'credi': 802,
#  u'montagna': 600,
#  u'scuse': 2648,
#  u'basteranno': 1778,
#  u'magazzino': 1754,
#  u'anche': 534,
#  u'd\xe0': 3184,
#  u'distrutto': 1327,
#  u'rime': 1652,
#  u'motta': 2973,
#  u'litigare': 301,
#  u'crescono': 2759,
#  u'cinte': 3369,
#  u'gratis': 3419,
#  u'negozi': 3529,
#  u'queste': 778,
#  u'urla': 756,
#  u'questa': 75,
#  u'consiglia': 2033,
#  u'questo': 826,
#  u'denti': 784,
#  u'compromesso': 2861,
#  u'una': 115,
#  u'insegne': 2213,
#  u'disag-io': 1604,
#  u'coi': 1090,
#  u'favore': 836,
#  u'tinge': 2479,
#  u'col': 133,
#  u'uno': 1076,
#  u'flavio': 2564,
#  u'pianto': 1123,
#  u'baciarti': 2274,
#  u'spezzati': 2909,
#  u'curare': 3344,
#  u'piante': 888,
#  u'portano': 214,
#  u'diventiamo': 1921,
#  u'funebre': 1051,
#  u'chiaro:': 1691,
#  u'matti': 2534,
#  u'strappo': 1156,
#  u'dipinti': 1095,
#  u'restarti': 427,
#  u'zitto': 684,
#  u'oooooo': 2523,
#  u"dov'ero": 2197,
#  u"quand'era": 2602,
#  u'petto': 1769,
#  u'imparare': 408,
#  u'scende': 343,
#  u'caff\xe8': 951,
#  u'abbracci': 2907,
#  u'life': 2121,
#  u'cio\xe8': 1067,
#  u'sperare': 2100,
#  u'correvamo': 2535,
#  u'gridandolo': 577,
#  u'pezzi': 1850,
#  u'ascoltami': 3242,
#  u'pezzo': 2394,
#  u'servito': 3481,
#  u'dipingerti': 2269,
#  u'aprire': 293,
#  u'perdevo': 2189,
#  u'militare': 3355,
#  u'avessimo': 1817,
#  u'guidate': 2338,
#  u'quaggi\xf9': 2159,
#  u'contare': 409,
#  u'assolato': 822,
#  u'avrei': 1172,
#  u'castro': 910,
#  u'dello': 1177,
#  u'forse': 237,
#  u'sapore': 365,
#  u'coglione': 3097,
#  u'delle': 882,
#  u'pagavo': 1751,
#  u'della': 868,
#  u'ritorni': 1620,
#  u'cane': 897,
#  u'ritorno': 401,
#  u"dall'elicottero": 2604,
#  u'indietro': 1004,
#  u'bio': 3411,
#  u'ritorna': 957,
#  u'distrazione': 2815,
#  u'it': 1719,
#  u'notti': 2920,
#  u'bruttissima': 2580,
#  u'il': 35,
#  u'io': 33,
#  u'in': 68,
#  u"l'insalata": 437,
#  u'sbagliata': 3244,
#  u'farsi': 1036,
#  u'ogni': 717,
#  u'bottiglie': 1825,
#  u'bello': 660,
#  u'lavorare': 1117,
#  u'belli': 2326,
#  u'nike': 1519,
#  u'belle': 1796,
#  u'scrivo': 1406,
#  u'aveva': 2109,
#  u'bella': 183,
#  u'citt\xe0': 157,
#  u'bastardo': 2212,
#  u'perfetto': 2854,
#  u'\ufffdsto': 1729,
#  u'salita': 2135,
#  u'consente': 2410,
#  u'manchi': 369,
#  u'finir\xe0': 2419,
#  u'regalarti': 1223,
#  u'consento': 606,
#  u'satelliti': 2310,
#  u"un'immagine": 965,
#  u'persa': 1541,
#  u'topi': 434,
#  u'fusa': 2588,
#  u'costruito': 2263,
#  u'passato': 2253,
#  u'traffico': 1520,
#  u'serate': 1671,
#  u'piazza': 1032,
#  u'presto': 1265,
#  u'subirlo': 3472,
#  u'orgasmo': 236,
#  u'"\n': 1427,
#  u'schiaccio': 1516,
#  u'mamma': 415,
#  u'sedia': 3313,
#  u'roma': 2795,
#  u'the': 1569,
#  u'tenerci': 1461,
#  u'borsa': 2066,
#  u'yeh': 1232,
#  u"l'indiano": 942,
#  u'amami': 1168,
#  u'cerchi': 2307,
#  u'prenditi': 2980,
#  u'chiuderti': 3439,
#  u'scoperto': 3463,
#  u'saltare': 916,
#  u'bubu': 1269,
#  u'disegno': 1144,
#  u'gode': 2007,
#  u'voglia': 203,
#  u'hai': 17,
#  u'sfidi': 1991,
#  u'han': 2819,
#  u'svegliare': 3065,
#  u'salutami': 414,
#  u'terrazza': 2845,
#  u'voglio': 395,
#  u'vuoti': 2923,
#  u'vuoto': 1547,
#  u'cucina': 1082,
#  u'scoperta': 2846,
#  u'vuote': 704,
#  u'migliori': 3219,
#  u'bastarda': 1664,
#  u'migliore': 2101,
#  u'online': 3414,
#  u'ricorder\xf3': 2544,
#  u'scatti': 1505,
#  u'capo': 328,
#  u"un'onda": 598,
#  u'ferragosto': 1118,
#  u'sapevo': 2207,
#  u'margherite': 2330,
#  u'nudo': 202,
#  u'prometto': 2709,
#  u'scarpe': 1580,
#  u'nudi': 2203,
#  u'nude': 1954,
#  u'sputare': 1649,
#  u'rotolano': 2073,
#  u'falla': 3433,
#  u'gandhi': 1918,
#  u"l'altro": 2409,
#  u'palchi': 1685,
#  u'clich\xe9': 1228,
#  u'verranno': 2933,
#  u'scuri': 1556,
#  u'parli': 1878,
#  u'scura': 1247,
#  u'neve': 885,
#  u'andartene': 2494,
#  u'ritroviamoci': 2947,
#  u'facendo': 1047,
#  u'fisso': 506,
#  u'finivano': 3007,
#  u'anello': 1224,
#  u"d'acqua": 3233,
#  u'gridare': 895,
#  u'correre': 2185,
#  u'silenzi': 2781,
#  u'decidono': 3148,
#  u'serpente': 892,
#  u'gradino': 2878,
#  u'globo': 940,
#  u'vede': 16,
#  u'uragano': 1934,
#  u'giocata': 3234,
#  u'l\u2019otto': 3515,
#  u'vedo': 445,
#  u'strade': 213,
#  u'strada': 865,
#  u'vedi': 336,
#  u'dolce': 953,
#  u'sarai': 2486,
#  u'lampo': 2152,
#  u'scordarti': 2480,
#  u'giacca': 1544,
#  u'opzioni': 1350,
#  u'collasso': 3522,
#  u'braccio': 1716,
#  u'braccia': 541,
#  u'trovartene': 2485,
#  u'neon': 3307,
#  u'cacciavo': 1428,
#  u'spaventa': 2076,
#  u'mancher\xf2': 152,
#  u'sbronzarmi': 3227,
#  u'ricordavi': 2884,
#  u'o': 70,
#  u'algi': 3427,
#  u'perplessit\xe0': 2995,
#  u'gioiello': 1226,
#  u'affogo': 2678,
#  u'bisogno': 2896,
#  u'dignit\xe0': 3123,
#  u'volerai': 2246,
#  u"un'amica": 267,
#  u'correndo': 3096,
#  u'dicevo': 3494,
#  u'cartina': 1836,
#  u'selfie': 3022,
#  u'specchio': 223,
#  u'nervi': 919,
#  u"d'affari": 3370,
#  u'son': 870,
#  u'mangiarsi': 2927,
#  u'rotto': 1160,
#  u'smetto': 1298,
#  u'dovevo': 2126,
#  u'risbatte': 188,
#  u'accarezza': 764,
#  u'andando': 2496,
#  u'rotte': 1824,
#  u'rotta': 1103,
#  u'n\xe9': 285,
#  u'accordi': 2064,
#  u'fiume': 1114,
#  u'ostacoli': 2285,
#  u'gregge': 1816,
#  u'rispondi': 197,
#  u'panorama': 749,
#  u'mordevi': 3386,
#  u'rispondo': 3060,
#  u'viso': 2658,
#  u'stipendio': 3415,
#  u'tombino': 2687,
#  u'lago': 599,
#  u'sembri': 2910,
#  u'streghe': 3457,
#  u'bagno': 556,
#  u'bagni': 2967,
#  u'rimettersi': 2318,
#  u"l'accender\xe0": 1838,
#  u'bagna': 3541,
#  u'stereo': 1772,
#  u'pochissime': 2962,
#  u'spunta': 3480,
#  u'bere': 393,
#  u'rivedo': 670,
#  u'verde': 518,
#  u'diventare': 2539,
#  u'ripercuote': 995,
#  u'ritroveremo': 823,
#  u'viva': 3462,
#  u'pesa': 1452,
#  u'vergognare': 2289,
#  u'all\u2019acqua': 3561,
#  u'streaming': 3398,
#  u'vorrei': 318,
#  u'polso': 3499,
#  u'manger\xf2': 3466,
#  u'vivo': 3459,
#  u'peso': 1283,
#  u'pagine': 2356,
#  u'crystal': 1280,
#  u'fermo': 835,
#  u'intero': 2306,
#  u'pagina': 2340,
#  u'moicani': 492,
#  u'ferma': 669,
#  u'mettermi': 1367,
#  u"c'\xe8": 477,
#  u'bicchiere': 453,
#  u'sudate': 3323,
#  u'rifiuti': 3471,
#  u'minaj': 1607,
#  u'tonno': 682,
#  u'saremo': 1898,
#  u'allontana': 1324,
#  u'maglie': 3239,
#  u'magnifico': 853,
#  u'vogliam': 3351,
#  u'guardarsi': 785,
#  u'stacco': 2395,
#  u'mutande': 216,
#  u'scritto': 1153,
#  u'tesi': 2716,
#  u'no': 425,
#  u'riparare': 3010,
#  u'visto': 504,
#  u'ne': 9,
#  u'gi\xf9': 400,
#  u'gi\xe0': 1300,
#  u'neanche': 1701,
#  u'commerciale': 2628,
#  u'likebella': 2430,
#  u'filanti': 2705,
#  u'levarci': 1463,
#  u'sballo': 3409,
#  u'troverei': 980,
#  u'canto': 63,
#  u'nodo': 2956,
#  u'muove': 1504,
#  u'richiamo': 1409,
#  u'dobbiamo': 1442,
#  u'sbaglia': 3283,
#  u'chiusa': 227,
#  u'lottato': 1397,
#  u'acqua': 603,
#  u'avanti': 1692,
#  u'fiorisce': 946,
#  u"all'altoparlante": 2192,
#  u'smentita': 2045,
#  u'sbaglio': 457,
#  u'chiuso': 196,
#  u'accosta': 1626,
#  u'quindi': 2676,
#  u'trib\xf9': 3443,
#  u'inutile': 1990,
#  u'seitan': 1598,
#  u'siedi': 3483,
#  u'distanza': 566,
#  u"dall'impatto": 2448,
#  u'lunga': 723,
#  u'occhiali': 855,
#  u"l'ascolto": 2444,
#  u'rom': 312,
#  u'salopette': 1966,
#  u'scioglie': 668,
#  u'cos\xec': 32,
#  u'soffro': 3111,
#  u'inesorabilmente': 562,
#  u'vacanza': 3528,
#  u'correr\xf2': 2546,
#  u'denso': 2315,
#  u'corpo': 2034,
#  u'tradirti': 819,
#  u'sanno': 1414,
#  u'viceversa': 1540,
#  u'sconosciuto': 1077,
#  u'centrifughe': 3410,
#  u'giacche': 1584,
#  u'torno': 399,
#  u'torna': 2223,
#  u'tonsille': 47,
#  u'puoi': 51,
#  u'l\u2019orecchio': 101,
#  u'quasi': 2756,
#  u'fenicottero': 2605,
#  u'provate': 1687,
#  u'portarmi': 3492,
#  u'preciso': 1802,
#  u'pettinavi': 2988,
#  u'finiscono': 2237,
#  u'pugno': 2057,
#  u"l'estate": 766,
#  u'votare': 1012,
#  u'pugni': 1862,
#  u'crescere': 1939,
#  u'allagare': 557,
#  u'minuto': 1695,
#  u'fratelli': 1632,
#  u'mordeva': 2672,
#  u'proteggi': 3288,
#  u'dio': 1653,
#  u'affollata': 3286,
#  u'fragile': 3006,
#  u'brindo': 1423,
#  u"d'ombretto": 2171,
#  u'posto': 128,
#  u'svelto': 498,
#  u'soffri': 2259,
#  u'continuate': 2132,
#  u'carte': 1586,
#  u'posti': 1317,
#  u'sciolgono': 1500,
#  u'poste': 709,
#  u'aperto': 607,
#  u'aperti': 675,
#  u'boccia': 2450,
#  u'guardando': 867,
#  u'suonatore': 1152,
#  u'cose': 126,
#  u'treno': 71,
#  u'treni': 582,
#  u'cosa': 182,
#  u'brava': 1180,
#  u'bravo': 1163,
#  u'intelligente': 347,
#  u'cosi': 1644,
#  u'iniziare': 1362,
#  u"l'abitudine": 2144,
#  u'sfogo': 1588,
#  u'celestini': 441,
#  u'vengo': 832,
#  u'nello': 1380,
#  u'starmene': 2721,
#  u'pianura': 245,
#  u'cassa': 2998,
#  u"dell'umore": 3546,
#  u'scade': 2874,
#  u'pessima': 2662,
#  u'berrettoqui': 3212,
#  u"s'avveri": 759,
#  u'uguali': 2361,
#  u'liquore': 2483,
#  u'agosto': 85,
#  u'saresti': 3571,
#  u'uguale': 1553,
#  u'macchine': 2005,
#  u'alzarmi': 1358,
#  u"l'amavo": 2114,
#  u'tira': 3320,
#  u'macchina': 859,
#  u'rinascere': 3271,
#  u'muovermi': 3383,
#  u're': 1895,
#  u'negli': 112,
#  u'dice': 1807,
#  u'alto': 1056,
#  u'probabilmente': 2115,
#  u'fenomeni': 874,
#  u"dell'estate": 2631,
#  u'dandogli': 2615,
#  u'buca': 1768,
#  u'alta': 3216,
#  u'boh': 1174,
#  u'molto': 647,
#  u'potrebbe': 1473,
#  u'sputi': 221,
#  u'graffi': 2532,
#  u'molte': 751,
#  u'l\u2019orologio': 3498,
#  u'molta': 927,
#  u'effetto': 1669,
#  u"t'incazzerai": 2364,
#  u'renato': 2403,
#  u'controllavo': 3502,
#  u'muscoli': 3114,
#  u'buttare': 388,
#  u'scommesse': 3413,
#  u'enorme': 2222,
#  u'italiano': 3535,
#  u'lasciati': 2804,
#  u'basterebbe': 3069,
#  u'lasciato': 93,
#  u'boschi': 1126,
#  u'luned\xec': 2526,
#  u'spaccher\xf2': 366,
#  u'taciturnal': 1498,
#  u'sentirti': 3072,
#  u'prova': 3473,
#  u'prove': 1897,
#  u'provi': 1780,
#  u'provo': 3132,
#  u'cavalli': 3576,
#  u'iphone': 1613,
#  u'ahhh': 2557,
#  u'annaffio': 3059,
#  u'gridare:': 2413,
#  u'servir\xf2': 2354,
#  u'ristoranti': 3042,
#  u'oooooooh': 2090,
#  u'salta': 757,
#  u'ooooooo': 2524,
#  u'ridere': 461,
#  u'ooooooh': 2071,
#  u'evitare': 3124,
#  ...}

# %%
# now tokenize the whole text file, using the dictionary created
token_text = []
with codecs.open(filename, 'r', 'utf-8') as f:
    for line in f:
        total_size += len(line)
        words = filter(lambda a: a != '', re.split('([\.\?\n\t\(\)\s,!"]+)', line))
        token_text += [token_to_idx[w.lower()] for w in words]

# %%
len(token_text)
# Out:
# 61580

# %%
# prepare the dataset of input sequences (10 words) to output (1 word) pairs
seq_length = 10 # length of word sequences used for predictions
dataX = []
dataY = []
for i in range(0, len(token_text) - seq_length):
    seq_in = token_text[i:i + seq_length]
    seq_out = token_text[i + seq_length]
    dataX.append(seq_in)
    dataY.append(seq_out)
n_patterns = len(dataX)
print "Total Patterns: ", n_patterns
# Out:
# Total Patterns:  61570

# %%
print dataX[0], '-->', dataY[0]
# Out:
# [1, 2, 3, 2, 4, 2, 5, 2, 6, 2] --> 7

# %%
# create numpy arrays from lists
X = np.reshape(np.array(dataX), (n_patterns, seq_length, 1))
y = np.array(dataY)

# %%
X.shape
# Out:
# (61570, 10, 1)

# %%
n_neurons = seq_length
n_epoch = 20
n_batch = 128

# %%
y = np_utils.to_categorical(y)

# %%
# create LSTM
model = Sequential()
model.add(LSTM(n_neurons, input_shape=X[0].shape))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 10)                480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3578)              39358
# =================================================================
# Total params: 39,838
# Trainable params: 39,838
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
filepath="model-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True,mode='min')
callbacks_l = [checkpoint]

# %%
# train LSTM
model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2, callbacks=callbacks_l)
# Out:
# Epoch 1/20
#  - 44s - loss: 5.7601
#
# Epoch 00001: loss improved from inf to 5.76015, saving model to model-01-5.7601.hdf5
# Epoch 2/20
#  - 52s - loss: 4.3195
#
# Epoch 00002: loss improved from 5.76015 to 4.31954, saving model to model-02-4.3195.hdf5
# Epoch 3/20
#  - 46s - loss: 4.2913
#
# Epoch 00003: loss improved from 4.31954 to 4.29127, saving model to model-03-4.2913.hdf5
# Epoch 4/20
#  - 44s - loss: 4.0876
#
# Epoch 00004: loss improved from 4.29127 to 4.08764, saving model to model-04-4.0876.hdf5
# Epoch 5/20
#  - 40s - loss: 3.8743
#
# Epoch 00005: loss improved from 4.08764 to 3.87427, saving model to model-05-3.8743.hdf5
# Epoch 6/20
#  - 40s - loss: 3.8021
#
# Epoch 00006: loss improved from 3.87427 to 3.80207, saving model to model-06-3.8021.hdf5
# Epoch 7/20
#  - 40s - loss: 3.7615
#
# Epoch 00007: loss improved from 3.80207 to 3.76150, saving model to model-07-3.7615.hdf5
# Epoch 8/20
#  - 40s - loss: 3.7406
#
# Epoch 00008: loss improved from 3.76150 to 3.74055, saving model to model-08-3.7406.hdf5
# Epoch 9/20
#  - 40s - loss: 3.7279
#
# Epoch 00009: loss improved from 3.74055 to 3.72788, saving model to model-09-3.7279.hdf5
# Epoch 10/20
#  - 41s - loss: 3.7125
#
# Epoch 00010: loss improved from 3.72788 to 3.71253, saving model to model-10-3.7125.hdf5
# Epoch 11/20
#  - 43s - loss: 3.7057
#
# Epoch 00011: loss improved from 3.71253 to 3.70572, saving model to model-11-3.7057.hdf5
# Epoch 12/20
#  - 43s - loss: 3.7020
#
# Epoch 00012: loss improved from 3.70572 to 3.70203, saving model to model-12-3.7020.hdf5
# Epoch 13/20
#  - 41s - loss: 3.6980
#
# Epoch 00013: loss improved from 3.70203 to 3.69800, saving model to model-13-3.6980.hdf5
# Epoch 14/20
#  - 44s - loss: 3.6904
#
# Epoch 00014: loss improved from 3.69800 to 3.69036, saving model to model-14-3.6904.hdf5
# Epoch 15/20
#  - 41s - loss: 3.6853
#
# Epoch 00015: loss improved from 3.69036 to 3.68527, saving model to model-15-3.6853.hdf5
# Epoch 16/20
#  - 47s - loss: 3.6775
#
# Epoch 00016: loss improved from 3.68527 to 3.67748, saving model to model-16-3.6775.hdf5
# Epoch 17/20
#  - 44s - loss: 3.6727
#
# Epoch 00017: loss improved from 3.67748 to 3.67268, saving model to model-17-3.6727.hdf5
# Epoch 18/20
#  - 42s - loss: 3.6587
#
# Epoch 00018: loss improved from 3.67268 to 3.65866, saving model to model-18-3.6587.hdf5
# Epoch 19/20
#  - 42s - loss: 3.6481
#
# Epoch 00019: loss improved from 3.65866 to 3.64806, saving model to model-19-3.6481.hdf5
# Epoch 20/20
#  - 42s - loss: 3.6400
#
# Epoch 00020: loss improved from 3.64806 to 3.64001, saving model to model-20-3.6400.hdf5

# %%
idx_to_token = dict()
for k in token_to_idx.iteritems():
    idx_to_token[k[1]] = k[0]

# %%
idx_to_token
# Out:
# {1: u'lo',
#  2: u' ',
#  3: u'sai',
#  4: u'che',
#  5: u'la',
#  6: u'tachipirina',
#  7: u'500',
#  8: u'se',
#  9: u'ne',
#  10: u'prendi',
#  11: u'due',
#  12: u'\n',
#  13: u'diventa',
#  14: u'1000',
#  15: u'si',
#  16: u'vede',
#  17: u'hai',
#  18: u'provato',
#  19: u'qualcosina',
#  20: u'parlano',
#  21: u'le',
#  22: u'tue',
#  23: u'pupille',
#  24: u'e',
#  25: u'adesso',
#  26: u'mi',
#  27: u'per',
#  28: u'mano',
#  29: u'vacci',
#  30: u'piano',
#  31: u'stringi',
#  32: u'cos\xec',
#  33: u'io',
#  34: u'sento',
#  35: u'il',
#  36: u'cuore',
#  37: u'a',
#  38: u'mille',
#  39: u'duomo',
#  40: u'di',
#  41: u'milano',
#  42: u'\xe8',
#  43: u'un',
#  44: u'paracetamolo',
#  45: u'sempre',
#  46: u'pronto',
#  47: u'tonsille',
#  48: u'domani',
#  49: u'non',
#  50: u'lavoro',
#  51: u'puoi',
#  52: u'venire',
#  53: u"po'",
#  54: u'da',
#  55: u'me',
#  56: u'ma',
#  57: u'poi',
#  58: u'vieni',
#  59: u'mai',
#  60: u'te',
#  61: u', ',
#  62: u'versailles',
#  63: u'canto',
#  64: u'gabbiano',
#  65: u'dentro',
#  66: u'mia',
#  67: u'siamo',
#  68: u'in',
#  69: u'metro',
#  70: u'o',
#  71: u'treno',
#  72: u'importa',
#  73: u'mar',
#  74: u'mediterraneo',
#  75: u'questa',
#  76: u'radio',
#  77: u'ti',
#  78: u'prego',
#  79: u'\t\n',
#  80: u'esco',
#  81: u'fuori',
#  82: u'caldo',
#  83: u'normale',
#  84: u'ad',
#  85: u'agosto',
#  86: u'ci',
#  87: u'penso',
#  88: u'sudo',
#  89: u'stesso',
#  90: u'un\u2019ombra',
#  91: u'sul',
#  92: u'soffitto',
#  93: u'lasciato',
#  94: u'nei',
#  95: u'sospiri',
#  96: u'nel',
#  97: u'letto',
#  98: u'filo',
#  99: u'voce',
#  100: u'ferro',
#  101: u'l\u2019orecchio',
#  102: u'dai',
#  103: u'fa',
#  104: u'niente',
#  105: u'richiamerai',
#  106: u'call',
#  107: u'center',
#  108: u'dir\xf2',
#  109: u'we',
#  110: u'deficiente',
#  111: u'!\n',
#  112: u'negli',
#  113: u'occhi',
#  114: u'ho',
#  115: u'una',
#  116: u'botte',
#  117: u'perde',
#  118: u'perch\xe9',
#  119: u'sono',
#  120: u'innamorato',
#  121: u'ero',
#  122: u'addormentato',
#  123: u'lasci',
#  124: u'solo',
#  125: u'con',
#  126: u'cose',
#  127: u'al',
#  128: u'posto',
#  129: u'loro',
#  130: u'notte',
#  131: u'mangio',
#  132: u'buio',
#  133: u'col',
#  134: u'pesto',
#  135: u'piace',
#  136: u'ingoio',
#  137: u'salvagente',
#  138: u'lascio',
#  139: u'andar',
#  140: u'via',
#  141: u'corrente',
#  142: u'riporta',
#  143: u'qui',
#  144: u'ricordi',
#  145: u'?\n',
#  146: u'andavamo',
#  147: u'passeggiare',
#  148: u'come',
#  149: u'fatto',
#  150: u'pi\xf9',
#  151: u'vero',
#  152: u'mancher\xf2',
#  153: u'mio',
#  154: u'sguardo',
#  155: u'lontano',
#  156: u'luci',
#  157: u'citt\xe0',
#  158: u'ah',
#  159: u'credessi',
#  160: u'tutto',
#  161: u'quel',
#  162: u'dici',
#  163: u'sarebbe',
#  164: u'certo',
#  165: u'rischio',
#  166: u'rimanere',
#  167: u'parole',
#  168: u'suonano',
#  169: u'ridicole',
#  170: u'mondo',
#  171: u'tavolo',
#  172: u'noi',
#  173: u'briciole',
#  174: u'tutti',
#  175: u'i',
#  176: u'giorni',
#  177: u'camminavi',
#  178: u'nebbia',
#  179: u'risvolti',
#  180: u'nubi',
#  181: u'amici',
#  182: u'cosa',
#  183: u'bella',
#  184: u'punteggiano',
#  185: u'discorsi',
#  186: u'tuoi',
#  187: u'saliva',
#  188: u'risbatte',
#  189: u'forte',
#  190: u'mare',
#  191: u'ai',
#  192: u'miei',
#  193: u'pensieri',
#  194: u'arriva',
#  195: u'parlo',
#  196: u'chiuso',
#  197: u'rispondi',
#  198: u'tanto',
#  199: u'fare',
#  200: u'metto',
#  201: u'davvero',
#  202: u'nudo',
#  203: u'voglia',
#  204: u'scopare',
#  205: u'servirebbe',
#  206: u'secondo',
#  207: u"all'anno",
#  208: u'respiro',
#  209: u'profondo',
#  210: u'rilassare',
#  211: u'spalle',
#  212: u'tutte',
#  213: u'strade',
#  214: u'portano',
#  215: u'alle',
#  216: u'mutande',
#  217: u'stai',
#  218: u"e'",
#  219: u'sacco',
#  220: u'offendi',
#  221: u'sputi',
#  222: u'allo',
#  223: u'specchio',
#  224: u'lavarti',
#  225: u'faccia',
#  226: u'bocca',
#  227: u'chiusa',
#  228: u'urlare',
#  229: u'tornato',
#  230: u'new',
#  231: u'york',
#  232: u'portato',
#  233: u'sopra',
#  234: u'scale',
#  235: u'chiesto',
#  236: u'orgasmo',
#  237: u'forse',
#  238: u'del',
#  239: u'ha',
#  240: u'dato',
#  241: u'altre',
#  242: u'campagne',
#  243: u'punto',
#  244: u'finisce',
#  245: u'pianura',
#  246: u' (',
#  247: u') ',
#  248: u'dove',
#  249: u'perdersi',
#  250: u'quando',
#  251: u'paura',
#  252: u'ecco',
#  253: u'bacio',
#  254: u'stampato',
#  255: u'fra',
#  256: u'mento',
#  257: u'scollatura',
#  258: u')\n',
#  259: u'perderti',
#  260: u'senti',
#  261: u'sola',
#  262: u'ieri',
#  263: u'comprato',
#  264: u"un'amaca",
#  265: u'salito',
#  266: u'incontrato',
#  267: u"un'amica",
#  268: u'tua',
#  269: u'tu-ru-tu-dum',
#  270: u' \n',
#  271: u'gaetano',
#  272: u'detto',
#  273: u'viviamo',
#  274: u'ghetto',
#  275: u'mentre',
#  276: u'dormissi',
#  277: u'disteso',
#  278: u'tuo',
#  279: u'lato',
#  280: u'sarei',
#  281: u'volevo',
#  282: u'avere',
#  283: u'dei',
#  284: u'figli',
#  285: u'n\xe9',
#  286: u'troppi',
#  287: u'pochi',
#  288: u'tardi',
#  289: u"l'inverno",
#  290: u'avanza',
#  291: u'tu',
#  292: u'vuoi',
#  293: u'aprire',
#  294: u"un'azienda",
#  295: u'tende',
#  296: u'mani',
#  297: u'svastica',
#  298: u'centro',
#  299: u'bologna',
#  300: u'era',
#  301: u'litigare',
#  302: u'far',
#  303: u'festa',
#  304: u'serviva',
#  305: u'pretesto',
#  306: u'lasciarti',
#  307: u'andare',
#  308: u'suona',
#  309: u'fisarmonica',
#  310: u'fiamme',
#  311: u'campo',
#  312: u'rom',
#  313: u'madre',
#  314: u'diceva',
#  315: u'su',
#  316: u'youporn',
#  317: u'verit\xe0',
#  318: u'vorrei',
#  319: u'accompagnare',
#  320: u'ancora',
#  321: u'quattro',
#  322: u'passi',
#  323: u'difficile',
#  324: u'vai',
#  325: u'veloce',
#  326: u'stare',
#  327: u'passo',
#  328: u'capo',
#  329: u'quante',
#  330: u'volte',
#  331: u'pensato',
#  332: u'alla',
#  333: u'fine',
#  334: u'sorriso',
#  335: u'parentesi',
#  336: u'vedi',
#  337: u'bene',
#  338: u'annoiavo',
#  339: u'feste',
#  340: u'cene',
#  341: u'paresi',
#  342: u'pioggia',
#  343: u'scende',
#  344: u'fredda',
#  345: u'pesaro',
#  346: u'donna',
#  347: u'intelligente',
#  348: u'eri',
#  349: u'fatta',
#  350: u'trasparente',
#  351: u'cascherai',
#  352: u'ami',
#  353: u'dovr\xf2',
#  354: u'soltanto',
#  355: u'reimparare',
#  356: u'camminare',
#  357: u'sei',
#  358: u'raggiungermi',
#  359: u'provare',
#  360: u'ricordami',
#  361: u'olive',
#  362: u'buone',
#  363: u'prender\xf2',
#  364: u'gelato',
#  365: u'sapore',
#  366: u'spaccher\xf2',
#  367: u'allora',
#  368: u'dimmi',
#  369: u'manchi',
#  370: u'mancheresti',
#  371: u'dichiaro',
#  372: u'tv',
#  373: u'voluto',
#  374: u'amore',
#  375: u'scomparire',
#  376: u'abbraccio',
#  377: u'confondermi',
#  378: u'dormire',
#  379: u'ed',
#  380: u'altri',
#  381: u'invece',
#  382: u'cui',
#  383: u'tornare',
#  384: u'riesco',
#  385: u'stasera',
#  386: u'possiamo',
#  387: u'cucinare',
#  388: u'buttare',
#  389: u'va',
#  390: u'disegnare',
#  391: u'dopo',
#  392: u'porti',
#  393: u'bere',
#  394: u'scusa',
#  395: u'voglio',
#  396: u'male',
#  397: u'so',
#  398: u'ospedale',
#  399: u'torno',
#  400: u'gi\xf9',
#  401: u'ritorno',
#  402: u'respirare',
#  403: u'morire',
#  404: u'rimango',
#  405: u'immaginare',
#  406: u'corsia',
#  407: u'mmm',
#  408: u'imparare',
#  409: u'contare',
#  410: u'spremi',
#  411: u'limonata',
#  412: u'ce',
#  413: u'fai',
#  414: u'salutami',
#  415: u'mamma',
#  416: u'tornata',
#  417: u'medjugorje',
#  418: u'padre',
#  419: u',\n',
#  420: u'ascolta',
#  421: u'de',
#  422: u'gregori',
#  423: u'tipo',
#  424: u'gente',
#  425: u'no',
#  426: u'proprio',
#  427: u'restarti',
#  428: u'accanto',
#  429: u'fossimo',
#  430: u'bambini',
#  431: u'guardare',
#  432: u'cielo',
#  433: u'fessure',
#  434: u'topi',
#  435: u'tombini',
#  436: u'giri',
#  437: u"l'insalata",
#  438: u'dieta',
#  439: u'vita',
#  440: u'taranta',
#  441: u'celestini',
#  442: u'bmw',
#  443: u'sto',
#  444: u'piedi',
#  445: u'vedo',
#  446: u'scoppi',
#  447: u'salute',
#  448: u'testa',
#  449: u'pizza',
#  450: u'sveglio',
#  451: u'tutta',
#  452: u'bevo',
#  453: u'bicchiere',
#  454: u'pensare',
#  455: u'meglio',
#  456: u'rivivere',
#  457: u'sbaglio',
#  458: u'mezzanotte',
#  459: u'commessi',
#  460: u'paio',
#  461: u'ridere',
#  462: u'cammino',
#  463: u'dritto',
#  464: u'fino',
#  465: u'risveglio',
#  466: u'stanotte',
#  467: u'america',
#  468: u'daremo',
#  469: u'figlio',
#  470: u'morir\xe0',
#  471: u'jihad',
#  472: u'chiedo',
#  473: u'tanti',
#  474: u'anni',
#  475: u'leggo',
#  476: u'giornale',
#  477: u"c'\xe8",
#  478: u'papa',
#  479: u'francesco',
#  480: u'frosinone',
#  481: u'serie',
#  482: u'vado',
#  483: u'corsa',
#  484: u'giro',
#  485: u'perdo',
#  486: u'parti',
#  487: u'giuro',
#  488: u'casa',
#  489: u'guardo',
#  490: u'film',
#  491: u"l'ultimo",
#  492: u'moicani',
#  493: u'chi',
#  494: u"l'appartamento",
#  495: u'rabbia',
#  496: u'lavato',
#  497: u'piatti',
#  498: u'svelto',
#  499: u'libert\xe0',
#  500: u'preferirei',
#  501: u'esistesse',
#  502: u'nemmeno',
#  503: u'abbia',
#  504: u'visto',
#  505: u'bosco',
#  506: u'fisso',
#  507: u'spiaggia',
#  508: u'sardegna',
#  509: u'scaldarmi',
#  510: u'legna',
#  511: u'prester\xf2',
#  512: u'soldi',
#  513: u'venirmi',
#  514: u'trovare',
#  515: u'vorrebbe',
#  516: u'viaggiare',
#  517: u'ricominciare',
#  518: u'verde',
#  519: u'intorno',
#  520: u'vestiti',
#  521: u'sandra',
#  522: u'faccio',
#  523: u'raimondo',
#  524: u'  \n',
#  525: u'barche',
#  526: u'mancano',
#  527: u'quelle',
#  528: u'conquistano',
#  529: u'resistendo',
#  530: u'instancabilmente',
#  531: u'agli',
#  532: u'attachi',
#  533: u'pirati',
#  534: u'anche',
#  535: u'imbarcazioni',
#  536: u'piccole',
#  537: u'costeggiavano',
#  538: u'reni',
#  539: u'quanto',
#  540: u'scemi',
#  541: u'braccia',
#  542: u'diventano',
#  543: u'remi',
#  544: u'quali',
#  545: u'gli',
#  546: u'uomini',
#  547: u'rigirano',
#  548: u"l'oceano",
#  549: u'scoprirne',
#  550: u'mistero',
#  551: u'frena',
#  552: u'dosso',
#  553: u'andiamo',
#  554: u'peschiera',
#  555: u'garda',
#  556: u'bagno',
#  557: u'allagare',
#  558: u'mansarda',
#  559: u'farmi',
#  560: u'raccontano',
#  561: u'galleggiando',
#  562: u'inesorabilmente',
#  563: u'far\xe0',
#  564: u'sentire',
#  565: u'soli',
#  566: u'distanza',
#  567: u'percorrono',
#  568: u'uccelli',
#  569: u'migratori',
#  570: u'avr\xf2',
#  571: u'l\u2019et\xe0',
#  572: u'diventer\xf2',
#  573: u'albero',
#  574: u'metter',
#  575: u'radici',
#  576: u'nelle',
#  577: u'gridandolo',
#  578: u'problemi',
#  579: u'porter\xf2',
#  580: u'letargo',
#  581: u'cassetto',
#  582: u'treni',
#  583: u'ritardo',
#  584: u'.\n',
#  585: u'immagini',
#  586: u'senza',
#  587: u'storia',
#  588: u'...\n',
#  589: u'ooh-ooh',
#  590: u'far\xf2',
#  591: u'scandalo',
#  592: u'meno',
#  593: u'sia',
#  594: u'un\u2019ora',
#  595: u'sa',
#  596: u'indovinato',
#  597: u'.',
#  598: u"un'onda",
#  599: u'lago',
#  600: u'montagna',
#  601: u'largo',
#  602: u'foglio',
#  603: u'acqua',
#  604: u'fuoco',
#  605: u'contraddico',
#  606: u'consento',
#  607: u'aperto',
#  608: u'valigia',
#  609: u'piena',
#  610: u'grande',
#  611: u'bambino',
#  612: u"all'acquario",
#  613: u'dallo',
#  614: u'squalo',
#  615: u'ballo',
#  616: u'prima',
#  617: u"dell'addio",
#  618: u'cambiato',
#  619: u'hey',
#  620: u'... ',
#  621: u'? ',
#  622: u'filosofi',
#  623: u'operai',
#  624: u'faccendieri',
#  625: u'disperati',
#  626: u'cinghiali',
#  627: u'incazzati',
#  628: u'uomo',
#  629: u'almeno',
#  630: u'sicuro',
#  631: u'foto',
#  632: u'ricordo',
#  633: u'vissuto',
#  634: u'allegra',
#  635: u'finale',
#  636: u'vino',
#  637: u'annacquato',
#  638: u'nascosto',
#  639: u"l'ho",
#  640: u'capito',
#  641: u'pinocchio',
#  642: u'appeso',
#  643: u'fiat',
#  644: u'oppure',
#  645: u'pesce',
#  646: u'rosso',
#  647: u'molto',
#  648: u'affezionato',
#  649: u'coda',
#  650: u"all'ingresso",
#  651: u'entro',
#  652: u'pieno',
#  653: u'.\t\n',
#  654: u'parlarti',
#  655: u'poco',
#  656: u'svegliarmi',
#  657: u'tra',
#  658: u'onde',
#  659: u'riflessi',
#  660: u'bello',
#  661: u'rincontrarti',
#  662: u'cerco',
#  663: u'cannocchiale',
#  664: u'guarda',
#  665: u'finta',
#  666: u'sabbia',
#  667: u'bollente',
#  668: u'scioglie',
#  669: u'ferma',
#  670: u'rivedo',
#  671: u'sotto',
#  672: u'camogli',
#  673: u'resto',
#  674: u'galla',
#  675: u'aperti',
#  676: u'. ',
#  677: u'riscoprirti',
#  678: u'balena',
#  679: u'cerca',
#  680: u'mangiare',
#  681: u'muovo',
#  682: u'tonno',
#  683: u'morto',
#  684: u'zitto',
#  685: u'piccolo',
#  686: u'sale',
#  687: u'sceglie',
#  688: u'sue',
#  689: u'sirene',
#  690: u'sta',
#  691: u'continua',
#  692: u'nuotare',
#  693: u'!\t\n',
#  694: u'giovani',
#  695: u"d'oggi",
#  696: u'valgono',
#  697: u'anziani',
#  698: u'hanno',
#  699: u'pregiudizi',
#  700: u'persone',
#  701: u'autostrade',
#  702: u'partiti',
#  703: u'scatole',
#  704: u'vuote',
#  705: u'costituzione',
#  706: u'bar',
#  707: u'sui',
#  708: u'metr\xf2',
#  709: u'poste',
#  710: u'cima',
#  711: u'monte',
#  712: u'fast',
#  713: u'food',
#  714: u'auto',
#  715: u'blu',
#  716: u'parlamento',
#  717: u'ogni',
#  718: u'momento',
#  719: u'capitato',
#  720: u'pronunciare',
#  721: u'frase\u2026',
#  722: u'ca**o',
#  723: u'lunga',
#  724: u'fila',
#  725: u'seconde',
#  726: u'case',
#  727: u'spiagge',
#  728: u'private',
#  729: u'salerno',
#  730: u'reggio-calabria',
#  731: u'esselunga',
#  732: u'miss',
#  733: u'italia',
#  734: u'lasciateci',
#  735: u'sbagliare',
#  736: u'seguendo',
#  737: u'nostre',
#  738: u'visioni',
#  739: u'scoprirete',
#  740: u'abbiamo',
#  741: u'qualcosa',
#  742: u'dare',
#  743: u'marzo',
#  744: u'vento',
#  745: u'luglio',
#  746: u"n'\xe8",
#  747: u'sera',
#  748: u'luce',
#  749: u'panorama',
#  750: u'accadono',
#  751: u'molte',
#  752: u"l'amore",
#  753: u'nasce',
#  754: u'autonomia',
#  755: u'corre',
#  756: u'urla',
#  757: u'salta',
#  758: u'lascia',
#  759: u"s'avveri",
#  760: u'frastuono',
#  761: u'musica',
#  762: u'viene',
#  763: u'nome',
#  764: u'accarezza',
#  765: u'invade',
#  766: u"l'estate",
#  767: u'picchia',
#  768: u'addosso',
#  769: u"l'alba",
#  770: u'illumina',
#  771: u'colore',
#  772: u'sfumatura',
#  773: u'capelli',
#  774: u'volto',
#  775: u'camminiamo',
#  776: u'insieme',
#  777: u'panino',
#  778: u'queste',
#  779: u'montagne',
#  780: u'stanno',
#  781: u'avveri',
#  782: u'svegliarsi',
#  783: u'lavarsi',
#  784: u'denti',
#  785: u'guardarsi',
#  786: u'lineamenti',
#  787: u'scoprire',
#  788: u'persona',
#  789: u'piangere',
#  790: u'buon',
#  791: u'amico',
#  792: u'stronzo',
#  793: u'mentito',
#  794: u's\xec',
#  795: u'lasciarmi',
#  796: u'saprei',
#  797: u'altro',
#  798: u"m'innamoro",
#  799: u'giocare',
#  800: u'ballare',
#  801: u'dico',
#  802: u'credi',
#  803: u'scappare',
#  804: u'ormai',
#  805: u'circondato',
#  806: u'dalla',
#  807: u'pelle',
#  808: u'sacra',
#  809: u'pella',
#  810: u'glabra',
#  811: u"l'unica",
#  812: u'stelle',
#  813: u'comprensione',
#  814: u'tempo',
#  815: u'starti',
#  816: u'ascoltare',
#  817: u'soluzione',
#  818: u"l'hai",
#  819: u'tradirti',
#  820: u'giorno',
#  821: u'buffo',
#  822: u'assolato',
#  823: u'ritroveremo',
#  824: u'bel',
#  825: u'aver',
#  826: u'questo',
#  827: u'nostro',
#  828: u'cervello',
#  829: u"dell'intero",
#  830: u'complesso',
#  831: u'spericolato',
#  832: u'vengo',
#  833: u'cercare',
#  834: u'meridionale',
#  835: u'fermo',
#  836: u'favore',
#  837: u'dire',
#  838: u'tranquillo',
#  839: u'trovo',
#  840: u'agito',
#  841: u'oh',
#  842: u'allegro',
#  843: u'dovrei',
#  844: u'aspettare',
#  845: u'sereno',
#  846: u'portiere',
#  847: u'calcio',
#  848: u'rigore',
#  849: u'aspetto',
#  850: u'spero',
#  851: u'calmo',
#  852: u'tramonto',
#  853: u'magnifico',
#  854: u'sole',
#  855: u'occhiali',
#  856: u'imbecilli',
#  857: u'pensano',
#  858: u"l'elefante",
#  859: u'macchina',
#  860: u'rossa',
#  861: u'lucente',
#  862: u'bici',
#  863: u'sobria',
#  864: u'elegante',
#  865: u'strada',
#  866: u'solamente',
#  867: u'guardando',
#  868: u'della',
#  869: u'luna',
#  870: u'son',
#  871: u'barca',
#  872: u'smettere',
#  873: u'fumare',
#  874: u'fenomeni',
#  875: u'ricordare',
#  876: u'cinghiale',
#  877: u'volta',
#  878: u'basta',
#  879: u'bastata',
#  880: u'ballerina',
#  881: u'ballava',
#  882: u'delle',
#  883: u'stupisco',
#  884: u'lavora',
#  885: u'neve',
#  886: u'dicembre',
#  887: u'saggezza',
#  888: u'piante',
#  889: u'pulito',
#  890: u'carne',
#  891: u'sorge',
#  892: u'serpente',
#  893: u'donare',
#  894: u'anno',
#  895: u'gridare',
#  896: u'sante',
#  897: u'cane',
#  898: u'sente',
#  899: u'dipende',
#  900: u'vicino',
#  901: u'armstrong',
#  902: u'vite',
#  903: u'finire',
#  904: u'schiacciando',
#  905: u'tasto',
#  906: u'uccidere',
#  907: u'castrol',
#  908: u'cuba',
#  909: u'morisse',
#  910: u'castro',
#  911: u'prete',
#  912: u'vestito',
#  913: u'alabastro',
#  914: u'parlar',
#  915: u'fame',
#  916: u'saltare',
#  917: u'pasto',
#  918: u'file',
#  919: u'nervi',
#  920: u"l'impasto",
#  921: u'nessuno',
#  922: u'parlare',
#  923: u'seduto',
#  924: u'locale',
#  925: u'qualcuno',
#  926: u'collane',
#  927: u'molta',
#  928: u'quanta',
#  929: u'produce',
#  930: u'porta',
#  931: u'chiunque',
#  932: u'dimentica',
#  933: u'ricorda',
#  934: u'(',
#  935: u'gioco',
#  936: u'vince',
#  937: u'grandissimo',
#  938: u'tifo',
#  939: u'diffuso',
#  940: u'globo',
#  941: u'sognavo',
#  942: u"l'indiano",
#  943: u'maggio',
#  944: u'porte',
#  945: u"l'acacia",
#  946: u'fiorisce',
#  947: u'buono',
#  948: u'profumo',
#  949: u'sposto',
#  950: u'vetrine',
#  951: u'caff\xe8',
#  952: u'clima',
#  953: u'dolce',
#  954: u'dal',
#  955: u'riprendo',
#  956: u"all'ombra",
#  957: u'ritorna',
#  958: u'capisco',
#  959: u'scadenza',
#  960: u'appuntamento',
#  961: u'chiama',
#  962: u'sentimento',
#  963: u"un'attitudine",
#  964: u'essere',
#  965: u"un'immagine",
#  966: u'dritta',
#  967: u'stacca',
#  968: u'riuscito',
#  969: u'rito',
#  970: u'riflesso',
#  971: u'dorme',
#  972: u'ama',
#  973: u'nuvole',
#  974: u'spara',
#  975: u'ammazza',
#  976: u'vivere',
#  977: u'leoni',
#  978: u'scimpanz\xe9',
#  979: u'li',
#  980: u'troverei',
#  981: u'maree',
#  982: u'gabbiani',
#  983: u'sogna',
#  984: u'foglie',
#  985: u'inganna',
#  986: u'devasta',
#  987: u'collegati',
#  988: u'strano',
#  989: u"dall'uomo",
#  990: u"nell'angolo",
#  991: u'sperduto',
#  992: u'recondito',
#  993: u'qualsiasi',
#  994: u'guerra',
#  995: u'ripercuote',
#  996: u'sulla',
#  997: u'terra',
#  998: u'vuole',
#  999: u'coraggio',
#  1000: u'reggere',
#  ...}

# %%
idx_to_token[100]
# Out:
# u'ferro'

# %%
n_vocab = len(token_to_idx)
# pick a random seed
start = np.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print "Seed:"
print "\"", ''.join([idx_to_token[value] for value in pattern]), "\""
# generate characters
for i in range(10):
    x = np.reshape(pattern, (1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = idx_to_token[index]
    #print "DBG ---- Pred:", result, "for", x
    seq_in = [idx_to_token[value] for value in pattern]
    print result,
    pattern.append(index)
    pattern = pattern[1:len(pattern)]
print "\nDone."
# Out:
# Seed:
# " giorno pagherò il conto
# quello  "
# che che che che che che che che che che
# Done.

# %%
value
# Out:
# 13
